# %% [markdown]
# # German Traffic Signs Detection
# ## Cargo 2017

# %% [markdown]
# ## GTSDB dataset analysis
# GTSDB is German traffic signs dataset and can be downloaded from [GTSDB](http://benchmark.ini.rub.de/?section=gtsdb&subsection=dataset)

# %% [markdown]
# ### 1、打印所有交通标记的信息，例如【单向行驶标记】有多少个图片

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

import os
os.getcwd()

# TrainIJCNN2013    '../data/TrainIJCNN2013/gt.txt'
#data = pd.read_csv('../data/TrainIJCNN2013/gt.txt', sep=";", header=None)

# FullIJCNN2013     '../data/FullIJCNN2013/gt.txt'
data = pd.read_csv('./data/FullIJCNN2013/gt.txt', sep=";", header=None)
data.columns = ["img", "x1", "y1", "x2", "y2", "id"]
#data=data[:3]

top3 = data[:3]
print("the top 3:\n", top3)
print("the top 3 id:\n", top3['id'])

# 741 张图片， 每张图片属于多个分类
print("Train has image files with traffic signs numbers:", len(data['img'].unique())) 

# 43 个分类
print("Train has traffic signs class numbers:", len(data['id'].unique()))

# 总共1213 条记录
print("Train has traffic signs instance numbers:", data['id'].count())

#pd.value_counts(data['id'], sort=False).plot.bar()
#打印每个分类的个数
print(pd.value_counts(data['id'], sort=True))
data['id'].hist(bins=86)
# Out:
# the top 3:
#           img   x1   y1    x2   y2  id
# 0  00000.ppm  774  411   815  446  11
# 1  00001.ppm  983  388  1024  432  40
# 2  00001.ppm  386  494   442  552  38
# the top 3 id:
#  0    11
# 1    40
# 2    38
# Name: id, dtype: int64
# Train has image files with traffic signs numbers: 741
# Train has traffic signs class numbers: 43
# Train has traffic signs instance numbers: 1213
# 38    88
# 12    85
# 13    83
# 2     81
# 10    80
# 1     79
# 4     68
# 8     57
# 5     53
# 9     41
# 7     41
# 11    38
# 18    38
# 14    32
# 25    31
# 3     30
# 17    29
# 23    20
# 35    20
# 6     19
# 26    18
# 30    16
# 33    16
# 15    15
# 28    14
# 22    13
# 34    12
# 42    11
# 40    10
# 20     9
# 36     9
# 32     8
# 16     8
# 41     7
# 39     6
# 21     5
# 24     5
# 29     5
# 0      4
# 27     3
# 19     2
# 31     2
# 37     2
# Name: id, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ### 2、 将各个分类标记进行【训练/测试/校验】的随机分段

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

print(sklearn.__version__)

data = pd.read_csv('./data/FullIJCNN2013/gt.txt', sep=";", header=None)
data.columns = ["img", "x1", "y1", "x2", "y2", "id"]

top3 = data[:3]
print("the top 3:\n", top3)

def stratifiedshufflesplit(data, train_size, test_size, thres=1):
    if train_size != None:
        test_size = 1.0 - train_size
    elif test_size != None:
        train_size = 1.0 - test_size
    else:
        raise IndexError("错误的比率")
    
    if train_size < 0.0 or test_size < 0.0:
        raise IndexError("错误的比率")
    
     
    # 将分类只有一条记录的数据，拼接到尾部
    y_less = data.groupby("id").filter(lambda x: len(x) <= thres)
    data = pd.concat([data, y_less], ignore_index=True)
    
    # 类型对应所有数量
    idValueList = data['id']
    #print('\nid value list:\n', idValueList)
    
    kf = KFold(n_splits=2, shuffle=True, random_state=42)
    #print('\nthe kf is:\n', kf)
    
    shuffles = np.hstack((next(kf.split(idValueList))))
    print("\nshuffles count:", len(shuffles))
    
    train_count = int(idValueList.count() * train_size)
    test_count = idValueList.count() - train_count
    print("\ntrain count:", train_count)
    print(  " test count:", test_count)
    
    xtrain, xtest = data.iloc[0:train_count,:], data.iloc[train_count:,:]
    #print("\ntrains:", len(xtrain), xtrain)
    #print("\n tests:", len(xtest), xtest)
    
    return xtrain, xtest

xtrain, xt = stratifiedshufflesplit(data, train_size=0.7, test_size=0.3, thres=1)
xtest, xval = stratifiedshufflesplit(xt, 0.5, 0.5, 1)
print("\ntop 3 train:", xtrain.head(3))
print("\ntop 3 test :", xtest.head(3))
print("\ntop 3 val  :", xval.head(3))
 
plt.hist([
        xtrain['id'], 
        #xt['id'],
        xtest['id'], 
        xval['id']
        ], 
        stacked=True, 
        label=["train", "test", "val"],
        bins=86
    )

plt.show()

xtrain['width'] = 1360
xtrain['height'] = 800
xtest['width'] = 1360
xtest['height'] = 800
xval['width'] = 1360
xval['height'] = 800
  
xtrain.to_csv('./data/png_FullIJCNN2013/train.csv', index=False)
xtest.to_csv('./data/png_FullIJCNN2013/test.csv', index=False)
xval.to_csv('./data/png_FullIJCNN2013/val.csv', index=False)
# Out:
# 0.23.2
# the top 3:
#           img   x1   y1    x2   y2  id
# 0  00000.ppm  774  411   815  446  11
# 1  00001.ppm  983  388  1024  432  40
# 2  00001.ppm  386  494   442  552  38
#
# shuffles count: 1213
#
# train count: 849
#  test count: 364
#
# shuffles count: 370
#
# train count: 185
#  test count: 185
#
# top 3 train:          img   x1   y1    x2   y2  id
# 0  00000.ppm  774  411   815  446  11
# 1  00001.ppm  983  388  1024  432  40
# 2  00001.ppm  386  494   442  552  38
#
# top 3 test :          img   x1   y1   x2   y2  id
# 0  00575.ppm  403  474  435  506  38
# 1  00593.ppm  584  510  608  534  38
# 2  00599.ppm  700  454  722  476   9
#
# top 3 val  :            img   x1   y1    x2   y2  id
# 185  00755.ppm  563  595   593  625  38
# 186  00756.ppm  881  524   931  574  12
# 187  00758.ppm  982  521  1014  553   8

# %% [markdown]
# ## Create Record and copy test images

# %%
import os
import hashlib
import io
import random
import tqdm
import shutil
import configparser
import pylab as plt
import tensorflow as tf
from tqdm import tqdm
from lxml import etree
from PIL import Image, ImageDraw, ImageFont
from object_detection.utils import dataset_util
from object_detection.utils import label_map_util
from collections import namedtuple, OrderedDict
import pandas as pd
from shutil import copyfile


def create_tf_record(examples_list, output_filename):
    print("Saving record file:", output_filename)
    writer = tf.compat.v1.python_io.TFRecordWriter(output_filename)
    for tf_example in examples_list:
        writer.write(tf_example.SerializeToString())
    writer.close()
    print("Successful created record files")

# 在图片 image 里绘制其对应的所有分类信息，包含框框 和 路标名字，并存储到png文件
def save_img_with_box(image, group, img_name, gt_label):
    for index, row in group.object.iterrows():
        x1 = row['x1']
        x2 = row['x2'] 
        y1 = row['y1'] 
        y2 = row['y2'] 
        class_id = int(row['id'])+1
        label = gt_label[class_id]
        
        box = (x1, y1), (x2, y2)
        #print(box, label, img_name)
        font = ImageFont.truetype(cf.get('font_path', 'Samyak'), 20)
        drawObject = ImageDraw.Draw(image)  
        drawObject.rectangle(box, outline = "red")  
        drawObject.text([x1+20, y1+20], label,"red", font=font)
    save_dir = target_dir
    if not os.path.exists(save_dir):
        os.makedirs(save_dir) 
    image.save(os.path.join(save_dir, img_name))
    #plt.imshow(image) 
    #plt.show()

def get_label_dict(label_path):
    label_map_dict = {}
    with open(label_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
        for line in lines:
            if not line.split():
                continue
            line = line.strip()
            number, name = line.split(' ', 1)
            #print(number, name)
            label_map_dict[int(number)] = name
    return label_map_dict

###########################################################
# img_path指定的图片，对应很多的分类，我们将这些分类打包成一组group
# 创建并返回 tensorflow example
def dict_to_tf_example(img_path,
                       group,
                       gt_label,
                       ignore_difficult_instances=False):
    """Convert gt derived dict to tf.Example proto.
    Notice that this function normalizes the bounding box coordinates provided
    by the raw data.
    """
    # 读取图片数据
    with tf.io.gfile.GFile(img_path, 'rb') as fid:
        encoded_jpg = fid.read()
    encoded_jpg_io = io.BytesIO(encoded_jpg)
    image = Image.open(encoded_jpg_io)
    
    width, height = image.size
    #print(image.size)
    #print(width, height)
    
    filename = (group.img[:-3] + 'png')
    image_format = b'png'
    xmin = []
    ymin = []
    xmax = []
    ymax = []
    classes = []
    classes_text = []
    
    # 遍历本图片组内的所有 分类信息
    # 进行normalized 成 [0,1],即将框框的4个角转换成浮点数
    for index, row in tqdm(group.object.iterrows()):
        #print(row['id'], gt_label[int(row['id'])+1])
        xmin.append(row['x1'] / width)
        xmax.append(row['x2'] / width)
        ymin.append(row['y1'] / height)
        ymax.append(row['y2'] / height)
        class_id = int(row['id'])+1
        classes_text.append(gt_label[class_id].encode('utf8'))
        classes.append(class_id)
    
    if save_img:    
        save_img_with_box(image, group, filename, gt_label)
    
    # 把一张图片里的所有object都装到example
    example = tf.train.Example(features=tf.train.Features(feature={
      'image/height': dataset_util.int64_feature(height),
      'image/width': dataset_util.int64_feature(width),
      'image/filename': dataset_util.bytes_feature(filename.encode('utf8')),
      'image/source_id': dataset_util.bytes_feature(filename.encode('utf8')),
      'image/encoded': dataset_util.bytes_feature(encoded_jpg),
      'image/format': dataset_util.bytes_feature(image_format),
      'image/object/bbox/xmin': dataset_util.float_list_feature(xmin),
      'image/object/bbox/xmax': dataset_util.float_list_feature(xmax),
      'image/object/bbox/ymin': dataset_util.float_list_feature(ymin),
      'image/object/bbox/ymax': dataset_util.float_list_feature(ymax),
      'image/object/class/text': dataset_util.bytes_list_feature(classes_text),
      'image/object/class/label': dataset_util.int64_list_feature(classes),
    }))
    return example

def split(df, group):
    data = namedtuple('data', ['img', 'object'])
    gb = df.groupby(group)
    return [data(img, gb.get_group(x)) for img, x in zip(gb.groups.keys(), gb.groups)]

#############################################################
# 按照gt_label 将cvs文件转变到 record文件
def csv_record(csv, gt_label, out='out.record'):
    # 加载csv样本文件
    examples = pd.read_csv(csv)
    
    # 按照img列进行打组， select * as `grouped` from `examples` group by 'img'
    grouped = split(examples, 'img')
    out_examples = []
    #print(grouped[:5])
    for group in tqdm(grouped):
        # 获取测试图片（需要将ppm后缀改为png）
        img_path = os.path.join(ppm_img_dir, group.img)
        #img_path = img_path[:-3] + "png"
        #print(group.img)
        #print("img_path:", img_path)
        tf_example = dict_to_tf_example(img_path, group, gt_label)
        out_examples.append(tf_example)
    
    output_dir = os.path.join(data_dir, 'records')
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)
    output = os.path.join(output_dir, out)
    create_tf_record(out_examples, output)
    print(out + ' has been successful created')
    
def main():
    '''
    train imgs eg:    ./data/TrainIJCNN2013/00039.ppm
    train gt:         ./data/TrainIJCNN2013/train.csv
    test imgs eg:     ./data/TestIJCNN2013/00043.ppm
    train.csv: 
        img,x1,y1,x2,y2,id,width,height
        00246.ppm,1091,354,1134,396,10,1360,800
    '''    
    
    # get label information 
    # label id = gt id + 1
    # 因为 gt.txt 记录的类型ID 是从0开始的，即49类的key为[0,48],
    # 而 gtsdb.label 文件的各个类别的 可视化名字，例如 第11类表示“禁止停车”，
    # 但是该文件记录的key范围是 [1,49],所以后续需要进行+1 的处理
    gt_label = get_label_dict(label_path)
    #print(gt_label[3])
    
    csv_record(train_gt_path, gt_label, 'train.record')
    csv_record(val_gt_path, gt_label, 'val.record')
  
    # copy images from test.csv to test_samples
    examples = pd.read_csv(test_gt_path)
    grouped = split(examples, 'img')
    #print(grouped[:5])
    #for group in grouped:
    #    img_path = os.path.join(train_img_dir, group.img)
    #    img_path = img_path[:-3] + "png"
    #    img_out = os.path.join(test_img_dir, group.img)
    #    img_out = img_out[:-3] + "png"
    #    copyfile(img_path, img_out)
    

save_img = True
data_dir = './data'
ppm_img_dir = os.path.join(data_dir, 'FullIJCNN2013')
train_img_dir = os.path.join(data_dir, 'png_FullIJCNN2013')
test_img_dir = os.path.join(data_dir, 'test_samples')
target_dir = os.path.join(data_dir, 'input_img_vis_test')

# 训练、测试、校验的标签文件
train_gt_path = os.path.join(train_img_dir, 'train.csv')
test_gt_path = os.path.join(train_img_dir,'test.csv')
val_gt_path = os.path.join(train_img_dir, 'val.csv')

# 各个类别对应的 信号名称
label_path = os.path.join(data_dir, 'gtsdb.label')

cf = configparser.ConfigParser()
cf.read('./config/traffic.config')

if __name__ == '__main__': 
    main()
# Out:
#   0%|          | 0/503 [00:00<?, ?it/s]
# 1it [00:00, 2835.91it/s]
#   0%|          | 1/503 [00:00<01:36,  5.19it/s]
# 3it [00:00, 6696.60it/s]
#   0%|          | 2/503 [00:00<01:32,  5.39it/s]
# 1it [00:00, 2902.63it/s]
#   1%|          | 3/503 [00:00<01:32,  5.42it/s]
# 3it [00:00, 6827.41it/s]
#   1%|          | 4/503 [00:00<01:29,  5.55it/s]
# 2it [00:00, 4488.29it/s]
#   1%|          | 5/503 [00:00<01:33,  5.35it/s]
# 1it [00:00, 3050.40it/s]
#   1%|          | 6/503 [00:01<01:32,  5.38it/s]
# 1it [00:00, 3575.71it/s]
#   1%|▏         | 7/503 [00:01<01:29,  5.54it/s]
# 1it [00:00, 3387.97it/s]
#   2%|▏         | 8/503 [00:01<01:27,  5.63it/s]
# 2it [00:00, 4238.81it/s]
#   2%|▏         | 9/503 [00:01<01:37,  5.05it/s]
# 1it [00:00, 3533.53it/s]
#   2%|▏         | 10/503 [00:01<01:45,  4.69it/s]
# 1it [00:00, 3527.59it/s]
#   2%|▏         | 11/503 [00:02<01:39,  4.97it/s]
# 2it [00:00, 4445.47it/s]
#   2%|▏         | 12/503 [00:02<01:33,  5.23it/s]
# 1it [00:00, 2293.22it/s]
#   3%|▎         | 13/503 [00:02<01:32,  5.28it/s]
# 1it [00:00, 2861.05it/s]
#   3%|▎         | 14/503 [00:02<01:27,  5.56it/s]
# 1it [00:00, 2959.99it/s]
#   3%|▎         | 15/503 [00:02<01:18,  6.24it/s]
# 1it [00:00, 3350.08it/s]
#   3%|▎         | 16/503 [00:02<01:24,  5.78it/s]
# 1it [00:00, 3243.85it/s]
#   3%|▎         | 17/503 [00:03<01:25,  5.68it/s]
# 2it [00:00, 5140.08it/s]
#   4%|▎         | 18/503 [00:03<01:44,  4.66it/s]
# 1it [00:00, 2709.50it/s]
#   4%|▍         | 19/503 [00:03<01:32,  5.21it/s]
# 2it [00:00, 5562.74it/s]
#   4%|▍         | 20/503 [00:03<01:27,  5.49it/s]
# 1it [00:00, 2978.91it/s]
#   4%|▍         | 21/503 [00:03<01:22,  5.82it/s]
# 1it [00:00, 3698.68it/s]
#   4%|▍         | 22/503 [00:04<01:34,  5.11it/s]
# 1it [00:00, 2611.65it/s]
#   5%|▍         | 23/503 [00:04<01:35,  5.05it/s]
# 3it [00:00, 6105.25it/s]
#   5%|▍         | 24/503 [00:04<01:32,  5.20it/s]
# 1it [00:00, 3429.52it/s]
#   5%|▍         | 25/503 [00:04<01:36,  4.97it/s]
# 2it [00:00, 4683.76it/s]
#   5%|▌         | 26/503 [00:04<01:37,  4.91it/s]
# 1it [00:00, 3398.95it/s]
#   5%|▌         | 27/503 [00:05<01:37,  4.89it/s]
# 2it [00:00, 5080.93it/s]
#   6%|▌         | 28/503 [00:05<01:28,  5.38it/s]
# 2it [00:00, 4860.14it/s]
#   6%|▌         | 29/503 [00:05<01:36,  4.89it/s]
# 1it [00:00, 2748.56it/s]
#   6%|▌         | 30/503 [00:05<01:37,  4.88it/s]
# 1it [00:00, 2678.36it/s]
#   6%|▌         | 31/503 [00:05<01:29,  5.29it/s]
# 2it [00:00, 5295.84it/s]
#   6%|▋         | 32/503 [00:06<01:23,  5.61it/s]
# 2it [00:00, 4490.69it/s]
#   7%|▋         | 33/503 [00:06<01:25,  5.52it/s]
# 1it [00:00, 1852.61it/s]
#   7%|▋         | 34/503 [00:06<01:23,  5.60it/s]
# 1it [00:00, 3443.60it/s]
#   7%|▋         | 35/503 [00:06<01:29,  5.24it/s]
# 2it [00:00, 5753.50it/s]
#   7%|▋         | 36/503 [00:06<01:22,  5.64it/s]
# 2it [00:00, 5940.94it/s]
#   7%|▋         | 37/503 [00:06<01:26,  5.40it/s]
# 1it [00:00, 2843.60it/s]
#   8%|▊         | 38/503 [00:07<01:32,  5.04it/s]
# 1it [00:00, 3435.14it/s]
#   8%|▊         | 39/503 [00:07<01:27,  5.28it/s]
# 2it [00:00, 4960.74it/s]
#   8%|▊         | 40/503 [00:07<01:28,  5.21it/s]
# 2it [00:00, 5857.97it/s]
#   8%|▊         | 41/503 [00:07<01:29,  5.18it/s]
# 1it [00:00, 3539.50it/s]
#   8%|▊         | 42/503 [00:07<01:31,  5.06it/s]
# 1it [00:00, 3355.44it/s]
#   9%|▊         | 43/503 [00:08<01:32,  4.99it/s]
# 3it [00:00, 4826.59it/s]
#   9%|▊         | 44/503 [00:08<01:35,  4.79it/s]
# 1it [00:00, 2251.37it/s]
#   9%|▉         | 45/503 [00:08<01:32,  4.93it/s]
# 1it [00:00, 3075.00it/s]
#   9%|▉         | 46/503 [00:08<01:33,  4.86it/s]
# 1it [00:00, 2642.91it/s]
#   9%|▉         | 47/503 [00:09<01:32,  4.92it/s]
# 1it [00:00, 3569.62it/s]
#  10%|▉         | 48/503 [00:09<01:26,  5.25it/s]
# 3it [00:00, 7589.21it/s]
#  10%|▉         | 49/503 [00:09<01:28,  5.13it/s]
# 2it [00:00, 5773.30it/s]
#  10%|▉         | 50/503 [00:09<01:27,  5.15it/s]
# 2it [00:00, 4213.26it/s]
#  10%|█         | 51/503 [00:09<01:27,  5.17it/s]
# 1it [00:00, 3542.49it/s]
#  10%|█         | 52/503 [00:09<01:31,  4.91it/s]
# 2it [00:00, 4908.49it/s]
#  11%|█         | 53/503 [00:10<01:32,  4.87it/s]
# 2it [00:00, 4798.97it/s]
#  11%|█         | 54/503 [00:10<01:36,  4.63it/s]
# 4it [00:00, 7323.10it/s]
#  11%|█         | 55/503 [00:10<01:31,  4.87it/s]
# 1it [00:00, 3692.17it/s]
#  11%|█         | 56/503 [00:10<01:29,  5.01it/s]
# 1it [00:00, 3287.07it/s]
#  11%|█▏        | 57/503 [00:11<01:30,  4.90it/s]
# 1it [00:00, 3515.76it/s]
#  12%|█▏        | 58/503 [00:11<01:25,  5.22it/s]
# 1it [00:00, 3070.50it/s]
#  12%|█▏        | 59/503 [00:11<01:23,  5.29it/s]
# 1it [00:00, 3279.36it/s]
#  12%|█▏        | 60/503 [00:11<01:19,  5.57it/s]
# 2it [00:00, 4637.15it/s]
#  12%|█▏        | 61/503 [00:11<01:21,  5.43it/s]
# 1it [00:00, 3644.05it/s]
#  12%|█▏        | 62/503 [00:11<01:21,  5.44it/s]
# 1it [00:00, 3377.06it/s]
#  13%|█▎        | 63/503 [00:12<01:18,  5.60it/s]
# 1it [00:00, 2783.21it/s]
#  13%|█▎        | 64/503 [00:12<01:19,  5.54it/s]
# 1it [00:00, 3603.35it/s]
#  13%|█▎        | 65/503 [00:12<01:18,  5.61it/s]
# 1it [00:00, 2327.58it/s]
#  13%|█▎        | 66/503 [00:12<01:24,  5.15it/s]
# 1it [00:00, 2555.94it/s]
#  13%|█▎        | 67/503 [00:12<01:22,  5.27it/s]
# 1it [00:00, 3292.23it/s]
#  14%|█▎        | 68/503 [00:13<01:23,  5.22it/s]
# 1it [00:00, 2741.38it/s]
#  14%|█▎        | 69/503 [00:13<01:18,  5.56it/s]
# 1it [00:00, 3575.71it/s]
#  14%|█▍        | 70/503 [00:13<01:18,  5.51it/s]
# 1it [00:00, 3600.26it/s]
#  14%|█▍        | 71/503 [00:13<01:24,  5.13it/s]
# 3it [00:00, 7445.51it/s]
#  14%|█▍        | 72/503 [00:13<01:22,  5.23it/s]
# 1it [00:00, 3650.40it/s]
#  15%|█▍        | 73/503 [00:13<01:25,  5.02it/s]
# 6it [00:00, 7981.55it/s]
#  15%|█▍        | 74/503 [00:14<01:23,  5.11it/s]
# 3it [00:00, 5108.77it/s]
#  15%|█▍        | 75/503 [00:14<01:22,  5.18it/s]
# 2it [00:00, 5394.60it/s]
#  15%|█▌        | 76/503 [00:14<01:20,  5.33it/s]
# 2it [00:00, 5862.06it/s]
#  15%|█▌        | 77/503 [00:14<01:19,  5.35it/s]
# 2it [00:00, 4851.71it/s]
#  16%|█▌        | 78/503 [00:14<01:16,  5.59it/s]
# 2it [00:00, 5849.80it/s]
#  16%|█▌        | 79/503 [00:15<01:18,  5.38it/s]
# 1it [00:00, 3578.76it/s]
#  16%|█▌        | 80/503 [00:15<01:15,  5.59it/s]
# 1it [00:00, 2955.82it/s]
#  16%|█▌        | 81/503 [00:15<01:18,  5.37it/s]
# 2it [00:00, 5017.11it/s]
#  16%|█▋        | 82/503 [00:15<01:15,  5.56it/s]
# 1it [00:00, 2700.78it/s]
#  17%|█▋        | 83/503 [00:15<01:20,  5.25it/s]
# 2it [00:00, 5570.12it/s]
#  17%|█▋        | 84/503 [00:15<01:12,  5.78it/s]
# 1it [00:00, 2966.27it/s]
#  17%|█▋        | 85/503 [00:16<01:12,  5.74it/s]
# 1it [00:00, 3466.37it/s]
#  17%|█▋        | 86/503 [00:16<01:13,  5.67it/s]
# 1it [00:00, 2704.26it/s]
#  17%|█▋        | 87/503 [00:16<01:19,  5.26it/s]
# 2it [00:00, 5637.51it/s]
#  17%|█▋        | 88/503 [00:16<01:23,  4.99it/s]
# 4it [00:00, 8656.97it/s]
#  18%|█▊        | 89/503 [00:17<01:27,  4.74it/s]
# 2it [00:00, 3070.50it/s]
#  18%|█▊        | 90/503 [00:17<01:32,  4.45it/s]
# 1it [00:00, 2878.73it/s]
#  18%|█▊        | 91/503 [00:17<01:35,  4.32it/s]
# 3it [00:00, 4936.41it/s]
#  18%|█▊        | 92/503 [00:17<01:35,  4.30it/s]
# 3it [00:00, 4003.47it/s]
#  18%|█▊        | 93/503 [00:17<01:34,  4.33it/s]
# 2it [00:00, 4490.69it/s]
#  19%|█▊        | 94/503 [00:18<01:31,  4.46it/s]
# 2it [00:00, 5825.42it/s]
#  19%|█▉        | 95/503 [00:18<01:29,  4.54it/s]
# 2it [00:00, 5077.85it/s]
#  19%|█▉        | 96/503 [00:18<01:28,  4.59it/s]
# 2it [00:00, 4163.08it/s]
#  19%|█▉        | 97/503 [00:18<01:28,  4.61it/s]
# 3it [00:00, 5756.14it/s]
#  19%|█▉        | 98/503 [00:19<01:27,  4.64it/s]
# 2it [00:00, 5679.49it/s]
#  20%|█▉        | 99/503 [00:19<01:28,  4.55it/s]
# 1it [00:00, 2492.16it/s]
#  20%|█▉        | 100/503 [00:19<01:27,  4.61it/s]
# 2it [00:00, 4483.49it/s]
#  20%|██        | 101/503 [00:19<01:26,  4.65it/s]
# 1it [00:00, 2542.00it/s]
#  20%|██        | 102/503 [00:19<01:24,  4.73it/s]
# 2it [00:00, 4319.57it/s]
#  20%|██        | 103/503 [00:20<01:20,  4.98it/s]
# 2it [00:00, 5450.69it/s]
#  21%|██        | 104/503 [00:20<01:24,  4.74it/s]
# 2it [00:00, 4431.38it/s]
#  21%|██        | 105/503 [00:20<01:23,  4.78it/s]
# 2it [00:00, 4777.11it/s]
#  21%|██        | 106/503 [00:20<01:20,  4.93it/s]
# 1it [00:00, 3276.80it/s]
#  21%|██▏       | 107/503 [00:20<01:17,  5.12it/s]
# 2it [00:00, 4686.37it/s]
#  21%|██▏       | 108/503 [00:21<01:13,  5.36it/s]
# 1it [00:00, 2841.67it/s]
#  22%|██▏       | 109/503 [00:21<01:12,  5.45it/s]
# 1it [00:00, 3269.14it/s]
#  22%|██▏       | 110/503 [00:21<01:10,  5.61it/s]
# 2it [00:00, 5533.38it/s]
#  22%|██▏       | 111/503 [00:21<01:09,  5.63it/s]
# 2it [00:00, 4657.75it/s]
#  22%|██▏       | 112/503 [00:21<01:08,  5.70it/s]
# 1it [00:00, 2916.76it/s]
#  22%|██▏       | 113/503 [00:21<01:10,  5.56it/s]
# 1it [00:00, 3682.44it/s]
#  23%|██▎       | 114/503 [00:22<01:10,  5.52it/s]
# 2it [00:00, 5256.02it/s]
#  23%|██▎       | 115/503 [00:22<01:09,  5.62it/s]
# 2it [00:00, 4688.99it/s]
#  23%|██▎       | 116/503 [00:22<01:10,  5.50it/s]
# 2it [00:00, 4826.59it/s]
#  23%|██▎       | 117/503 [00:22<01:09,  5.57it/s]
# 1it [00:00, 3127.74it/s]
#  23%|██▎       | 118/503 [00:22<01:10,  5.47it/s]
# 2it [00:00, 5216.80it/s]
#  24%|██▎       | 119/503 [00:22<01:09,  5.54it/s]
# 1it [00:00, 3634.58it/s]
#  24%|██▍       | 120/503 [00:23<01:10,  5.41it/s]
# 1it [00:00, 2600.31it/s]
#  24%|██▍       | 121/503 [00:23<01:06,  5.76it/s]
# 2it [00:00, 4015.61it/s]
#  24%|██▍       | 122/503 [00:23<01:10,  5.44it/s]
# 2it [00:00, 4588.95it/s]
#  24%|██▍       | 123/503 [00:23<01:13,  5.15it/s]
# 2it [00:00, 5155.87it/s]
#  25%|██▍       | 124/503 [00:23<01:13,  5.18it/s]
# 1it [00:00, 3480.75it/s]
#  25%|██▍       | 125/503 [00:24<01:21,  4.62it/s]
# 2it [00:00, 5223.29it/s]
#  25%|██▌       | 126/503 [00:24<01:22,  4.59it/s]
# 2it [00:00, 5272.54it/s]
#  25%|██▌       | 127/503 [00:24<01:20,  4.68it/s]
# 1it [00:00, 2402.24it/s]
#  25%|██▌       | 128/503 [00:24<01:17,  4.82it/s]
# 2it [00:00, 3958.76it/s]
#  26%|██▌       | 129/503 [00:25<01:18,  4.77it/s]
# 3it [00:00, 6982.75it/s]
#  26%|██▌       | 130/503 [00:25<01:21,  4.59it/s]
# 2it [00:00, 5629.94it/s]
#  26%|██▌       | 131/503 [00:25<01:22,  4.50it/s]
# 1it [00:00, 2920.82it/s]
#  26%|██▌       | 132/503 [00:25<01:23,  4.45it/s]
# 3it [00:00, 6339.00it/s]
#  26%|██▋       | 133/503 [00:25<01:23,  4.46it/s]
# 1it [00:00, 2614.90it/s]
#  27%|██▋       | 134/503 [00:26<01:25,  4.30it/s]
# 1it [00:00, 3492.34it/s]
#  27%|██▋       | 135/503 [00:26<01:27,  4.19it/s]
# 1it [00:00, 3418.34it/s]
#  27%|██▋       | 136/503 [00:26<01:29,  4.11it/s]
# 1it [00:00, 3211.57it/s]
#  27%|██▋       | 137/503 [00:26<01:27,  4.17it/s]
# 2it [00:00, 5440.08it/s]
#  27%|██▋       | 138/503 [00:27<01:20,  4.56it/s]
# 1it [00:00, 3241.35it/s]
#  28%|██▊       | 139/503 [00:27<01:16,  4.73it/s]
# 1it [00:00, 2900.63it/s]
#  28%|██▊       | 140/503 [00:27<01:14,  4.86it/s]
# 1it [00:00, 3342.07it/s]
#  28%|██▊       | 141/503 [00:27<01:13,  4.92it/s]
# 1it [00:00, 3426.72it/s]
#  28%|██▊       | 142/503 [00:27<01:14,  4.83it/s]
# 1it [00:00, 3609.56it/s]
#  28%|██▊       | 143/503 [00:28<01:14,  4.83it/s]
# 3it [00:00, 7401.71it/s]
#  29%|██▊       | 144/503 [00:28<01:12,  4.98it/s]
# 1it [00:00, 3761.71it/s]
#  29%|██▉       | 145/503 [00:28<01:10,  5.09it/s]
# 1it [00:00, 2614.90it/s]
#  29%|██▉       | 146/503 [00:28<01:09,  5.11it/s]
# 3it [00:00, 7345.54it/s]
#  29%|██▉       | 147/503 [00:28<01:10,  5.08it/s]
# 1it [00:00, 3440.77it/s]
#  29%|██▉       | 148/503 [00:29<01:08,  5.15it/s]
# 1it [00:00, 3472.11it/s]
#  30%|██▉       | 149/503 [00:29<01:08,  5.19it/s]
# 1it [00:00, 3109.19it/s]
#  30%|██▉       | 150/503 [00:29<01:07,  5.23it/s]
# 1it [00:00, 3454.95it/s]
#  30%|███       | 151/503 [00:29<01:10,  5.02it/s]
# 1it [00:00, 3622.02it/s]
#  30%|███       | 152/503 [00:29<01:08,  5.11it/s]
# 1it [00:00, 2861.05it/s]
#  30%|███       | 153/503 [00:30<01:09,  5.04it/s]
# 1it [00:00, 2673.23it/s]
#  31%|███       | 154/503 [00:30<01:11,  4.87it/s]
# 3it [00:00, 7117.03it/s]
#  31%|███       | 155/503 [00:30<01:08,  5.07it/s]
# 1it [00:00, 2910.69it/s]
#  31%|███       | 156/503 [00:30<01:09,  5.00it/s]
# 4it [00:00, 8688.36it/s]
#  31%|███       | 157/503 [00:30<01:08,  5.02it/s]
# 1it [00:00, 3336.76it/s]
#  31%|███▏      | 158/503 [00:31<01:06,  5.19it/s]
# 1it [00:00, 3521.67it/s]
#  32%|███▏      | 159/503 [00:31<01:05,  5.24it/s]
# 3it [00:00, 6944.21it/s]
#  32%|███▏      | 160/503 [00:31<01:04,  5.29it/s]
# 1it [00:00, 2671.53it/s]
#  32%|███▏      | 161/503 [00:31<01:07,  5.06it/s]
# 1it [00:00, 2613.27it/s]
#  32%|███▏      | 162/503 [00:31<01:06,  5.12it/s]
# 2it [00:00, 4688.99it/s]
#  32%|███▏      | 163/503 [00:32<01:08,  4.96it/s]
# 1it [00:00, 2924.90it/s]
#  33%|███▎      | 164/503 [00:32<01:08,  4.93it/s]
# 2it [00:00, 4984.32it/s]
#  33%|███▎      | 165/503 [00:32<01:08,  4.95it/s]
# 1it [00:00, 2264.74it/s]
#  33%|███▎      | 166/503 [00:32<01:11,  4.73it/s]
# 1it [00:00, 2882.68it/s]
#  33%|███▎      | 167/503 [00:32<01:11,  4.72it/s]
# 1it [00:00, 2910.69it/s]
#  33%|███▎      | 168/503 [00:33<01:10,  4.76it/s]
# 2it [00:00, 5504.34it/s]
#  34%|███▎      | 169/503 [00:33<01:09,  4.77it/s]
# 2it [00:00, 3994.58it/s]
#  34%|███▍      | 170/503 [00:33<01:09,  4.82it/s]
# 1it [00:00, 3194.44it/s]
#  34%|███▍      | 171/503 [00:33<01:08,  4.84it/s]
# 3it [00:00, 5518.82it/s]
#  34%|███▍      | 172/503 [00:33<01:08,  4.86it/s]
# 1it [00:00, 2737.80it/s]
#  34%|███▍      | 173/503 [00:34<01:08,  4.80it/s]
# 1it [00:00, 2866.92it/s]
#  35%|███▍      | 174/503 [00:34<01:11,  4.61it/s]
# 4it [00:00, 8783.88it/s]
#  35%|███▍      | 175/503 [00:34<01:11,  4.58it/s]
# 1it [00:00, 2855.21it/s]
#  35%|███▍      | 176/503 [00:34<01:11,  4.55it/s]
# 1it [00:00, 2137.77it/s]
#  35%|███▌      | 177/503 [00:35<01:12,  4.51it/s]
# 1it [00:00, 2746.76it/s]
#  35%|███▌      | 178/503 [00:35<01:12,  4.48it/s]
# 1it [00:00, 3028.38it/s]
#  36%|███▌      | 179/503 [00:35<01:08,  4.70it/s]
# 2it [00:00, 4350.94it/s]
#  36%|███▌      | 180/503 [00:35<01:08,  4.70it/s]
# 1it [00:00, 3048.19it/s]
#  36%|███▌      | 181/503 [00:35<01:07,  4.77it/s]
# 1it [00:00, 3167.90it/s]
#  36%|███▌      | 182/503 [00:36<01:07,  4.76it/s]
# 1it [00:00, 3498.17it/s]
#  36%|███▋      | 183/503 [00:36<01:07,  4.71it/s]
# 3it [00:00, 7580.07it/s]
#  37%|███▋      | 184/503 [00:36<01:07,  4.74it/s]
# 2it [00:00, 4366.79it/s]
#  37%|███▋      | 185/503 [00:36<01:06,  4.79it/s]
# 1it [00:00, 2935.13it/s]
#  37%|███▋      | 186/503 [00:36<01:06,  4.75it/s]
# 1it [00:00, 3019.66it/s]
#  37%|███▋      | 187/503 [00:37<01:06,  4.72it/s]
# 1it [00:00, 3004.52it/s]
#  37%|███▋      | 188/503 [00:37<01:09,  4.55it/s]
# 1it [00:00, 3072.75it/s]
#  38%|███▊      | 189/503 [00:37<01:09,  4.50it/s]
# 3it [00:00, 6894.75it/s]
#  38%|███▊      | 190/503 [00:37<01:09,  4.53it/s]
# 1it [00:00, 3672.77it/s]
#  38%|███▊      | 191/503 [00:38<01:09,  4.52it/s]
# 1it [00:00, 3266.59it/s]
#  38%|███▊      | 192/503 [00:38<01:11,  4.32it/s]
# 2it [00:00, 5737.76it/s]
#  38%|███▊      | 193/503 [00:38<01:14,  4.14it/s]
# 3it [00:00, 6746.87it/s]
#  39%|███▊      | 194/503 [00:38<01:12,  4.29it/s]
# 1it [00:00, 2294.48it/s]
#  39%|███▉      | 195/503 [00:39<01:13,  4.18it/s]
# 2it [00:00, 5729.92it/s]
#  39%|███▉      | 196/503 [00:39<01:13,  4.20it/s]
# 1it [00:00, 2730.67it/s]
#  39%|███▉      | 197/503 [00:39<01:12,  4.23it/s]
# 4it [00:00, 7692.44it/s]
#  39%|███▉      | 198/503 [00:39<01:11,  4.29it/s]
# 1it [00:00, 3248.88it/s]
#  40%|███▉      | 199/503 [00:40<01:14,  4.08it/s]
# 2it [00:00, 4969.55it/s]
#  40%|███▉      | 200/503 [00:40<01:10,  4.28it/s]
# 1it [00:00, 2608.40it/s]
#  40%|███▉      | 201/503 [00:40<01:12,  4.17it/s]
# 2it [00:00, 5415.50it/s]
#  40%|████      | 202/503 [00:40<01:18,  3.85it/s]
# 1it [00:00, 3587.94it/s]
#  40%|████      | 203/503 [00:41<01:23,  3.61it/s]
# 5it [00:00, 9374.84it/s]
#  41%|████      | 204/503 [00:41<01:18,  3.79it/s]
# 1it [00:00, 2953.74it/s]
#  41%|████      | 205/503 [00:41<01:18,  3.81it/s]
# 1it [00:00, 3339.41it/s]
#  41%|████      | 206/503 [00:41<01:17,  3.82it/s]
# 2it [00:00, 5870.26it/s]
#  41%|████      | 207/503 [00:42<01:17,  3.83it/s]
# 2it [00:00, 4493.09it/s]
#  41%|████▏     | 208/503 [00:42<01:14,  3.98it/s]
# 1it [00:00, 3631.43it/s]
#  42%|████▏     | 209/503 [00:42<01:12,  4.05it/s]
# 3it [00:00, 6011.90it/s]
#  42%|████▏     | 210/503 [00:42<01:09,  4.23it/s]
# 2it [00:00, 5821.38it/s]
#  42%|████▏     | 211/503 [00:42<01:05,  4.45it/s]
# 1it [00:00, 3521.67it/s]
#  42%|████▏     | 212/503 [00:43<01:02,  4.63it/s]
# 2it [00:00, 3874.65it/s]
#  42%|████▏     | 213/503 [00:43<01:01,  4.69it/s]
# 1it [00:00, 2721.81it/s]
#  43%|████▎     | 214/503 [00:43<01:02,  4.64it/s]
# 1it [00:00, 2688.66it/s]
#  43%|████▎     | 215/503 [00:43<01:00,  4.80it/s]
# 2it [00:00, 5789.24it/s]
#  43%|████▎     | 216/503 [00:44<00:58,  4.89it/s]
# 1it [00:00, 2933.08it/s]
#  43%|████▎     | 217/503 [00:44<00:59,  4.79it/s]
# 1it [00:00, 2656.30it/s]
#  43%|████▎     | 218/503 [00:44<01:00,  4.74it/s]
# 1it [00:00, 2768.52it/s]
#  44%|████▎     | 219/503 [00:44<00:59,  4.75it/s]
# 1it [00:00, 2748.56it/s]
#  44%|████▎     | 220/503 [00:44<00:58,  4.83it/s]
# 3it [00:00, 6072.83it/s]
#  44%|████▍     | 221/503 [00:45<00:58,  4.78it/s]
# 1it [00:00, 2912.71it/s]
#  44%|████▍     | 222/503 [00:45<00:59,  4.71it/s]
# 1it [00:00, 2991.66it/s]
#  44%|████▍     | 223/503 [00:45<00:59,  4.71it/s]
# 1it [00:00, 2618.17it/s]
#  45%|████▍     | 224/503 [00:45<00:57,  4.85it/s]
# 1it [00:00, 3165.51it/s]
#  45%|████▍     | 225/503 [00:45<00:55,  5.01it/s]
# 3it [00:00, 6058.21it/s]
#  45%|████▍     | 226/503 [00:46<00:56,  4.89it/s]
# 2it [00:00, 5059.47it/s]
#  45%|████▌     | 227/503 [00:46<00:58,  4.70it/s]
# 1it [00:00, 2995.93it/s]
#  45%|████▌     | 228/503 [00:46<00:57,  4.76it/s]
# 3it [00:00, 5863.43it/s]
#  46%|████▌     | 229/503 [00:46<00:57,  4.75it/s]
# 1it [00:00, 2851.33it/s]
#  46%|████▌     | 230/503 [00:46<00:55,  4.91it/s]
# 1it [00:00, 2926.94it/s]
#  46%|████▌     | 231/503 [00:47<00:55,  4.94it/s]
# 1it [00:00, 2976.79it/s]
#  46%|████▌     | 232/503 [00:47<00:57,  4.71it/s]
# 2it [00:00, 3856.83it/s]
#  46%|████▋     | 233/503 [00:47<00:55,  4.82it/s]
# 2it [00:00, 5702.66it/s]
#  47%|████▋     | 234/503 [00:47<00:54,  4.89it/s]
# 3it [00:00, 7649.19it/s]
#  47%|████▋     | 235/503 [00:47<00:54,  4.95it/s]
# 1it [00:00, 2649.59it/s]
#  47%|████▋     | 236/503 [00:48<00:54,  4.90it/s]
# 1it [00:00, 3132.42it/s]
#  47%|████▋     | 237/503 [00:48<00:53,  4.97it/s]
# 2it [00:00, 4894.17it/s]
#  47%|████▋     | 238/503 [00:48<00:54,  4.87it/s]
# 1it [00:00, 3015.32it/s]
#  48%|████▊     | 239/503 [00:48<00:55,  4.72it/s]
# 2it [00:00, 6026.30it/s]
#  48%|████▊     | 240/503 [00:49<00:55,  4.73it/s]
# 2it [00:00, 5099.46it/s]
#  48%|████▊     | 241/503 [00:49<00:57,  4.58it/s]
# 2it [00:00, 2299.51it/s]
#  48%|████▊     | 242/503 [00:49<00:55,  4.67it/s]
# 2it [00:00, 5450.69it/s]
#  48%|████▊     | 243/503 [00:49<00:55,  4.72it/s]
# 2it [00:00, 6034.97it/s]
#  49%|████▊     | 244/503 [00:49<00:53,  4.82it/s]
# 1it [00:00, 2792.48it/s]
#  49%|████▊     | 245/503 [00:50<00:54,  4.77it/s]
# 2it [00:00, 4238.81it/s]
#  49%|████▉     | 246/503 [00:50<00:53,  4.80it/s]
# 1it [00:00, 2750.36it/s]
#  49%|████▉     | 247/503 [00:50<00:53,  4.74it/s]
# 2it [00:00, 4546.67it/s]
#  49%|████▉     | 248/503 [00:50<00:53,  4.80it/s]
# 1it [00:00, 2736.01it/s]
#  50%|████▉     | 249/503 [00:50<00:53,  4.73it/s]
# 2it [00:00, 4888.47it/s]
#  50%|████▉     | 250/503 [00:51<00:52,  4.79it/s]
# 1it [00:00, 3165.51it/s]
#  50%|████▉     | 251/503 [00:51<00:53,  4.72it/s]
# 1it [00:00, 2641.25it/s]
#  50%|█████     | 252/503 [00:51<00:52,  4.75it/s]
# 2it [00:00, 4556.55it/s]
#  50%|█████     | 253/503 [00:51<00:51,  4.87it/s]
# 2it [00:00, 4507.58it/s]
#  50%|█████     | 254/503 [00:51<00:50,  4.96it/s]
# 1it [00:00, 3489.44it/s]
#  51%|█████     | 255/503 [00:52<00:49,  4.98it/s]
# 1it [00:00, 2987.40it/s]
#  51%|█████     | 256/503 [00:52<00:50,  4.91it/s]
# 1it [00:00, 3515.76it/s]
#  51%|█████     | 257/503 [00:52<00:48,  5.03it/s]
# 2it [00:00, 5641.30it/s]
#  51%|█████▏    | 258/503 [00:52<00:49,  4.95it/s]
# 1it [00:00, 2528.21it/s]
#  51%|█████▏    | 259/503 [00:52<00:48,  5.04it/s]
# 3it [00:00, 7639.90it/s]
#  52%|█████▏    | 260/503 [00:53<00:49,  4.95it/s]
# 3it [00:00, 5822.73it/s]
#  52%|█████▏    | 261/503 [00:53<00:49,  4.84it/s]
# 1it [00:00, 2870.84it/s]
#  52%|█████▏    | 262/503 [00:53<00:49,  4.82it/s]
# 2it [00:00, 4897.03it/s]
#  52%|█████▏    | 263/503 [00:53<00:50,  4.77it/s]
# 1it [00:00, 2937.19it/s]
#  52%|█████▏    | 264/503 [00:53<00:49,  4.82it/s]
# 1it [00:00, 2788.77it/s]
#  53%|█████▎    | 265/503 [00:54<00:49,  4.81it/s]
# 3it [00:00, 7153.45it/s]
#  53%|█████▎    | 266/503 [00:54<00:48,  4.87it/s]
# 2it [00:00, 4165.15it/s]
#  53%|█████▎    | 267/503 [00:54<00:46,  5.04it/s]
# 2it [00:00, 4144.57it/s]
#  53%|█████▎    | 268/503 [00:54<00:47,  4.97it/s]
# 1it [00:00, 2673.23it/s]
#  53%|█████▎    | 269/503 [00:54<00:47,  4.97it/s]
# 1it [00:00, 2718.28it/s]
#  54%|█████▎    | 270/503 [00:55<00:48,  4.85it/s]
# 2it [00:00, 4807.23it/s]
#  54%|█████▍    | 271/503 [00:55<00:48,  4.75it/s]
# 2it [00:00, 4350.94it/s]
#  54%|█████▍    | 272/503 [00:55<00:49,  4.67it/s]
# 1it [00:00, 2671.53it/s]
#  54%|█████▍    | 273/503 [00:55<00:51,  4.51it/s]
# 2it [00:00, 5252.73it/s]
#  54%|█████▍    | 274/503 [00:56<00:52,  4.35it/s]
# 1it [00:00, 2987.40it/s]
#  55%|█████▍    | 275/503 [00:56<00:52,  4.34it/s]
# 2it [00:00, 5475.59it/s]
#  55%|█████▍    | 276/503 [00:56<00:51,  4.40it/s]
# 2it [00:00, 5710.42it/s]
#  55%|█████▌    | 277/503 [00:56<00:49,  4.60it/s]
# 1it [00:00, 2964.17it/s]
#  55%|█████▌    | 278/503 [00:56<00:47,  4.72it/s]
# 1it [00:00, 3578.76it/s]
#  55%|█████▌    | 279/503 [00:57<00:47,  4.75it/s]
# 2it [00:00, 5289.16it/s]
#  56%|█████▌    | 280/503 [00:57<00:45,  4.90it/s]
# 1it [00:00, 3631.43it/s]
#  56%|█████▌    | 281/503 [00:57<00:44,  5.04it/s]
# 1it [00:00, 3415.56it/s]
#  56%|█████▌    | 282/503 [00:57<00:44,  4.95it/s]
# 1it [00:00, 3155.98it/s]
#  56%|█████▋    | 283/503 [00:57<00:42,  5.14it/s]
# 2it [00:00, 5343.06it/s]
#  56%|█████▋    | 284/503 [00:58<00:45,  4.79it/s]
# 2it [00:00, 5641.30it/s]
#  57%|█████▋    | 285/503 [00:58<00:47,  4.60it/s]
# 1it [00:00, 2853.27it/s]
#  57%|█████▋    | 286/503 [00:58<00:49,  4.40it/s]
# 1it [00:00, 2792.48it/s]
#  57%|█████▋    | 287/503 [00:58<00:52,  4.10it/s]
# 2it [00:00, 5813.31it/s]
#  57%|█████▋    | 288/503 [00:59<00:52,  4.07it/s]
# 2it [00:00, 4860.14it/s]
#  57%|█████▋    | 289/503 [00:59<00:52,  4.05it/s]
# 2it [00:00, 5773.30it/s]
#  58%|█████▊    | 290/503 [00:59<00:55,  3.86it/s]
# 2it [00:00, 4996.19it/s]
#  58%|█████▊    | 291/503 [00:59<00:54,  3.91it/s]
# 2it [00:00, 4183.84it/s]
#  58%|█████▊    | 292/503 [01:00<00:49,  4.24it/s]
# 2it [00:00, 5518.82it/s]
#  58%|█████▊    | 293/503 [01:00<00:47,  4.39it/s]
# 3it [00:00, 6765.01it/s]
#  58%|█████▊    | 294/503 [01:00<00:47,  4.43it/s]
# 1it [00:00, 3179.91it/s]
#  59%|█████▊    | 295/503 [01:00<00:45,  4.58it/s]
# 2it [00:00, 5387.67it/s]
#  59%|█████▉    | 296/503 [01:01<00:44,  4.62it/s]
# 2it [00:00, 5691.05it/s]
#  59%|█████▉    | 297/503 [01:01<00:44,  4.63it/s]
# 1it [00:00, 3734.91it/s]
#  59%|█████▉    | 298/503 [01:01<00:45,  4.54it/s]
# 1it [00:00, 2616.53it/s]
#  59%|█████▉    | 299/503 [01:01<00:44,  4.59it/s]
# 1it [00:00, 3785.47it/s]
#  60%|█████▉    | 300/503 [01:01<00:44,  4.60it/s]
# 2it [00:00, 6034.97it/s]
#  60%|█████▉    | 301/503 [01:02<00:42,  4.71it/s]
# 2it [00:00, 4925.78it/s]
#  60%|██████    | 302/503 [01:02<00:42,  4.77it/s]
# 4it [00:00, 8220.10it/s]
#  60%|██████    | 303/503 [01:02<00:42,  4.70it/s]
# 2it [00:00, 5315.97it/s]
#  60%|██████    | 304/503 [01:02<00:40,  4.89it/s]
# 2it [00:00, 6052.39it/s]
#  61%|██████    | 305/503 [01:02<00:40,  4.91it/s]
# 2it [00:00, 5996.15it/s]
#  61%|██████    | 306/503 [01:03<00:40,  4.88it/s]
# 3it [00:00, 7380.01it/s]
#  61%|██████    | 307/503 [01:03<00:40,  4.80it/s]
# 1it [00:00, 3554.49it/s]
#  61%|██████    | 308/503 [01:03<00:40,  4.80it/s]
# 2it [00:00, 5493.52it/s]
#  61%|██████▏   | 309/503 [01:03<00:38,  5.04it/s]
# 2it [00:00, 5140.08it/s]
#  62%|██████▏   | 310/503 [01:03<00:38,  5.01it/s]
# 4it [00:00, 7377.84it/s]
#  62%|██████▏   | 311/503 [01:04<00:38,  5.00it/s]
# 1it [00:00, 3653.57it/s]
#  62%|██████▏   | 312/503 [01:04<00:38,  4.93it/s]
# 2it [00:00, 5026.13it/s]
#  62%|██████▏   | 313/503 [01:04<00:40,  4.66it/s]
# 2it [00:00, 5789.24it/s]
#  62%|██████▏   | 314/503 [01:04<00:39,  4.83it/s]
# 2it [00:00, 5050.34it/s]
#  63%|██████▎   | 315/503 [01:04<00:40,  4.68it/s]
# 2it [00:00, 5236.33it/s]
#  63%|██████▎   | 316/503 [01:05<00:41,  4.47it/s]
# 2it [00:00, 5302.53it/s]
#  63%|██████▎   | 317/503 [01:05<00:42,  4.42it/s]
# 1it [00:00, 3492.34it/s]
#  63%|██████▎   | 318/503 [01:05<00:38,  4.82it/s]
# 2it [00:00, 4321.80it/s]
#  63%|██████▎   | 319/503 [01:05<00:34,  5.37it/s]
# 2it [00:00, 5903.31it/s]
#  64%|██████▎   | 320/503 [01:05<00:33,  5.38it/s]
# 1it [00:00, 2941.31it/s]
#  64%|██████▍   | 321/503 [01:06<00:33,  5.40it/s]
# 4it [00:00, 8981.38it/s]
#  64%|██████▍   | 322/503 [01:06<00:36,  5.00it/s]
# 2it [00:00, 4581.44it/s]
#  64%|██████▍   | 323/503 [01:06<00:34,  5.23it/s]
# 3it [00:00, 6890.97it/s]
#  64%|██████▍   | 324/503 [01:06<00:34,  5.12it/s]
# 1it [00:00, 3390.71it/s]
#  65%|██████▍   | 325/503 [01:06<00:37,  4.71it/s]
# 2it [00:00, 4657.75it/s]
#  65%|██████▍   | 326/503 [01:07<00:38,  4.56it/s]
# 1it [00:00, 2723.57it/s]
#  65%|██████▌   | 327/503 [01:07<00:37,  4.70it/s]
# 2it [00:00, 5757.45it/s]
#  65%|██████▌   | 328/503 [01:07<00:41,  4.23it/s]
# 1it [00:00, 2970.47it/s]
#  65%|██████▌   | 329/503 [01:07<00:38,  4.53it/s]
# 1it [00:00, 3748.26it/s]
#  66%|██████▌   | 330/503 [01:08<00:40,  4.26it/s]
# 2it [00:00, 5457.78it/s]
#  66%|██████▌   | 331/503 [01:08<00:41,  4.11it/s]
# 2it [00:00, 6021.97it/s]
#  66%|██████▌   | 332/503 [01:08<00:40,  4.25it/s]
# 1it [00:00, 2785.06it/s]
#  66%|██████▌   | 333/503 [01:08<00:40,  4.18it/s]
# 2it [00:00, 5555.37it/s]
#  66%|██████▋   | 334/503 [01:09<00:41,  4.03it/s]
# 2it [00:00, 5346.47it/s]
#  67%|██████▋   | 335/503 [01:09<00:38,  4.39it/s]
# 1it [00:00, 2568.47it/s]
#  67%|██████▋   | 336/503 [01:09<00:34,  4.86it/s]
# 2it [00:00, 6013.34it/s]
#  67%|██████▋   | 337/503 [01:09<00:39,  4.22it/s]
# 2it [00:00, 6109.69it/s]
#  67%|██████▋   | 338/503 [01:10<00:38,  4.34it/s]
# 1it [00:00, 3536.51it/s]
#  67%|██████▋   | 339/503 [01:10<00:35,  4.56it/s]
# 2it [00:00, 5096.36it/s]
#  68%|██████▊   | 340/503 [01:10<00:37,  4.31it/s]
# 2it [00:00, 4675.92it/s]
#  68%|██████▊   | 341/503 [01:10<00:36,  4.38it/s]
# 1it [00:00, 2826.35it/s]
#  68%|██████▊   | 342/503 [01:10<00:37,  4.34it/s]
# 2it [00:00, 4471.54it/s]
#  68%|██████▊   | 343/503 [01:11<00:39,  4.04it/s]
# 4it [00:00, 8050.49it/s]
#  68%|██████▊   | 344/503 [01:11<00:35,  4.52it/s]
# 4it [00:00, 7895.16it/s]
#  69%|██████▊   | 345/503 [01:11<00:35,  4.43it/s]
# 2it [00:00, 5023.12it/s]
#  69%|██████▉   | 346/503 [01:11<00:36,  4.26it/s]
# 4it [00:00, 8966.98it/s]
#  69%|██████▉   | 347/503 [01:12<00:39,  3.99it/s]
# 4it [00:00, 8952.62it/s]
#  69%|██████▉   | 348/503 [01:12<00:39,  3.89it/s]
# 1it [00:00, 3506.94it/s]
#  69%|██████▉   | 349/503 [01:12<00:38,  4.00it/s]
# 1it [00:00, 3634.58it/s]
#  70%|██████▉   | 350/503 [01:12<00:37,  4.07it/s]
# 2it [00:00, 5710.42it/s]
#  70%|██████▉   | 351/503 [01:13<00:36,  4.12it/s]
# 2it [00:00, 4637.15it/s]
#  70%|██████▉   | 352/503 [01:13<00:39,  3.85it/s]
# 1it [00:00, 3708.49it/s]
#  70%|███████   | 353/503 [01:13<00:39,  3.75it/s]
# 2it [00:00, 6000.43it/s]
#  70%|███████   | 354/503 [01:13<00:39,  3.76it/s]
# 4it [00:00, 7453.23it/s]
#  71%|███████   | 355/503 [01:14<00:39,  3.78it/s]
# 2it [00:00, 4894.17it/s]
#  71%|███████   | 356/503 [01:14<00:42,  3.46it/s]
# 4it [00:00, 8363.52it/s]
#  71%|███████   | 357/503 [01:14<00:42,  3.43it/s]
# 4it [00:00, 4918.56it/s]
#  71%|███████   | 358/503 [01:15<00:44,  3.24it/s]
# 4it [00:00, 7433.41it/s]
#  71%|███████▏  | 359/503 [01:15<00:46,  3.08it/s]
# 2it [00:00, 5200.62it/s]
#  72%|███████▏  | 360/503 [01:15<00:47,  3.04it/s]
# 2it [00:00, 5924.16it/s]
#  72%|███████▏  | 361/503 [01:16<00:46,  3.03it/s]
# 2it [00:00, 5472.02it/s]
#  72%|███████▏  | 362/503 [01:16<00:48,  2.93it/s]
# 2it [00:00, 5936.74it/s]
#  72%|███████▏  | 363/503 [01:16<00:42,  3.29it/s]
# 2it [00:00, 5729.92it/s]
#  72%|███████▏  | 364/503 [01:17<00:44,  3.13it/s]
# 1it [00:00, 2514.57it/s]
#  73%|███████▎  | 365/503 [01:17<00:42,  3.28it/s]
# 2it [00:00, 4522.16it/s]
#  73%|███████▎  | 366/503 [01:17<00:43,  3.16it/s]
# 2it [00:00, 5833.52it/s]
#  73%|███████▎  | 367/503 [01:18<00:41,  3.29it/s]
# 1it [00:00, 3615.78it/s]
#  73%|███████▎  | 368/503 [01:18<00:38,  3.55it/s]
# 1it [00:00, 2526.69it/s]
#  73%|███████▎  | 369/503 [01:18<00:36,  3.69it/s]
# 2it [00:00, 5443.61it/s]
#  74%|███████▎  | 370/503 [01:18<00:35,  3.71it/s]
# 2it [00:00, 5246.16it/s]
#  74%|███████▍  | 371/503 [01:19<00:32,  4.10it/s]
# 2it [00:00, 4524.60it/s]
#  74%|███████▍  | 372/503 [01:19<00:32,  4.07it/s]
# 3it [00:00, 7252.40it/s]
#  74%|███████▍  | 373/503 [01:19<00:29,  4.40it/s]
# 1it [00:00, 3524.63it/s]
#  74%|███████▍  | 374/503 [01:19<00:29,  4.38it/s]
# 2it [00:00, 5611.11it/s]
#  75%|███████▍  | 375/503 [01:19<00:30,  4.18it/s]
# 1it [00:00, 3371.63it/s]
#  75%|███████▍  | 376/503 [01:20<00:30,  4.13it/s]
# 4it [00:00, 7426.83it/s]
#  75%|███████▍  | 377/503 [01:20<00:28,  4.36it/s]
# 2it [00:00, 4609.13it/s]
#  75%|███████▌  | 378/503 [01:20<00:28,  4.42it/s]
# 3it [00:00, 6805.25it/s]
#  75%|███████▌  | 379/503 [01:20<00:28,  4.40it/s]
# 4it [00:00, 7381.09it/s]
#  76%|███████▌  | 380/503 [01:21<00:29,  4.12it/s]
# 2it [00:00, 5555.37it/s]
#  76%|███████▌  | 381/503 [01:21<00:30,  3.96it/s]
# 1it [00:00, 2796.20it/s]
#  76%|███████▌  | 382/503 [01:21<00:29,  4.12it/s]
# 3it [00:00, 6940.38it/s]
#  76%|███████▌  | 383/503 [01:21<00:30,  3.99it/s]
# 1it [00:00, 3518.71it/s]
#  76%|███████▋  | 384/503 [01:22<00:28,  4.20it/s]
# 1it [00:00, 3024.01it/s]
#  77%|███████▋  | 385/503 [01:22<00:28,  4.19it/s]
# 1it [00:00, 2706.00it/s]
#  77%|███████▋  | 386/503 [01:22<00:27,  4.29it/s]
# 1it [00:00, 2912.71it/s]
#  77%|███████▋  | 387/503 [01:22<00:26,  4.32it/s]
# 1it [00:00, 2935.13it/s]
#  77%|███████▋  | 388/503 [01:22<00:24,  4.63it/s]
# 1it [00:00, 2741.38it/s]
#  77%|███████▋  | 389/503 [01:23<00:24,  4.70it/s]
# 2it [00:00, 4798.97it/s]
#  78%|███████▊  | 390/503 [01:23<00:25,  4.38it/s]
# 1it [00:00, 3163.13it/s]
#  78%|███████▊  | 391/503 [01:23<00:26,  4.24it/s]
# 2it [00:00, 5559.05it/s]
#  78%|███████▊  | 392/503 [01:24<00:29,  3.76it/s]
# 1it [00:00, 2711.25it/s]
#  78%|███████▊  | 393/503 [01:24<00:27,  3.97it/s]
# 1it [00:00, 1929.30it/s]
#  78%|███████▊  | 394/503 [01:24<00:30,  3.61it/s]
# 2it [00:00, 5797.24it/s]
#  79%|███████▊  | 395/503 [01:24<00:30,  3.49it/s]
# 4it [00:00, 7869.24it/s]
#  79%|███████▊  | 396/503 [01:25<00:32,  3.26it/s]
# 1it [00:00, 3088.59it/s]
#  79%|███████▉  | 397/503 [01:25<00:32,  3.24it/s]
# 1it [00:00, 3360.82it/s]
#  79%|███████▉  | 398/503 [01:25<00:31,  3.37it/s]
# 2it [00:00, 4975.45it/s]
#  79%|███████▉  | 399/503 [01:26<00:30,  3.37it/s]
# 1it [00:00, 3575.71it/s]
#  80%|███████▉  | 400/503 [01:26<00:27,  3.74it/s]
# 2it [00:00, 5581.24it/s]
#  80%|███████▉  | 401/503 [01:26<00:27,  3.65it/s]
# 2it [00:00, 5497.12it/s]
#  80%|███████▉  | 402/503 [01:26<00:28,  3.56it/s]
# 1it [00:00, 3653.57it/s]
#  80%|████████  | 403/503 [01:27<00:26,  3.78it/s]
# 1it [00:00, 3310.42it/s]
#  80%|████████  | 404/503 [01:27<00:24,  3.98it/s]
# 1it [00:00, 2634.61it/s]
#  81%|████████  | 405/503 [01:27<00:23,  4.18it/s]
# 1it [00:00, 3498.17it/s]
#  81%|████████  | 406/503 [01:27<00:25,  3.84it/s]
# 2it [00:00, 5486.34it/s]
#  81%|████████  | 407/503 [01:28<00:25,  3.78it/s]
# 1it [00:00, 3093.14it/s]
#  81%|████████  | 408/503 [01:28<00:25,  3.70it/s]
# 1it [00:00, 2922.86it/s]
#  81%|████████▏ | 409/503 [01:28<00:25,  3.62it/s]
# 1it [00:00, 3368.92it/s]
#  82%|████████▏ | 410/503 [01:28<00:24,  3.80it/s]
# 4it [00:00, 4389.64it/s]
#  82%|████████▏ | 411/503 [01:29<00:24,  3.79it/s]
# 4it [00:00, 5785.25it/s]
#  82%|████████▏ | 412/503 [01:29<00:26,  3.48it/s]
# 2it [00:00, 4165.15it/s]
#  82%|████████▏ | 413/503 [01:29<00:27,  3.32it/s]
# 3it [00:00, 4547.49it/s]
#  82%|████████▏ | 414/503 [01:30<00:24,  3.58it/s]
# 1it [00:00, 2099.25it/s]
#  83%|████████▎ | 415/503 [01:30<00:22,  3.91it/s]
# 1it [00:00, 2566.89it/s]
#  83%|████████▎ | 416/503 [01:30<00:22,  3.92it/s]
# 2it [00:00, 3443.60it/s]
#  83%|████████▎ | 417/503 [01:30<00:21,  4.02it/s]
# 1it [00:00, 2555.94it/s]
#  83%|████████▎ | 418/503 [01:31<00:20,  4.05it/s]
# 1it [00:00, 2360.33it/s]
#  83%|████████▎ | 419/503 [01:31<00:20,  4.08it/s]
# 1it [00:00, 2517.59it/s]
#  83%|████████▎ | 420/503 [01:31<00:19,  4.32it/s]
# 3it [00:00, 5019.11it/s]
#  84%|████████▎ | 421/503 [01:31<00:18,  4.41it/s]
# 1it [00:00, 2523.65it/s]
#  84%|████████▍ | 422/503 [01:32<00:19,  4.09it/s]
# 1it [00:00, 2387.20it/s]
#  84%|████████▍ | 423/503 [01:32<00:18,  4.37it/s]
# 2it [00:00, 3833.92it/s]
#  84%|████████▍ | 424/503 [01:32<00:17,  4.43it/s]
# 1it [00:00, 2535.85it/s]
#  84%|████████▍ | 425/503 [01:32<00:18,  4.24it/s]
# 2it [00:00, 4084.04it/s]
#  85%|████████▍ | 426/503 [01:32<00:17,  4.35it/s]
# 2it [00:00, 3173.90it/s]
#  85%|████████▍ | 427/503 [01:33<00:16,  4.68it/s]
# 1it [00:00, 2270.87it/s]
#  85%|████████▌ | 428/503 [01:33<00:15,  4.78it/s]
# 1it [00:00, 2647.92it/s]
#  85%|████████▌ | 429/503 [01:33<00:14,  4.94it/s]
# 1it [00:00, 2659.67it/s]
#  85%|████████▌ | 430/503 [01:33<00:15,  4.80it/s]
# 4it [00:00, 4832.15it/s]
#  86%|████████▌ | 431/503 [01:33<00:15,  4.66it/s]
# 1it [00:00, 2177.73it/s]
#  86%|████████▌ | 432/503 [01:34<00:15,  4.62it/s]
# 1it [00:00, 1986.88it/s]
#  86%|████████▌ | 433/503 [01:34<00:15,  4.55it/s]
# 3it [00:00, 3606.45it/s]
#  86%|████████▋ | 434/503 [01:34<00:15,  4.53it/s]
# 1it [00:00, 1957.21it/s]
#  86%|████████▋ | 435/503 [01:34<00:15,  4.52it/s]
# 1it [00:00, 2029.17it/s]
#  87%|████████▋ | 436/503 [01:35<00:14,  4.58it/s]
# 2it [00:00, 4443.12it/s]
#  87%|████████▋ | 437/503 [01:35<00:15,  4.29it/s]
# 2it [00:00, 5315.97it/s]
#  87%|████████▋ | 438/503 [01:35<00:16,  3.93it/s]
# 1it [00:00, 3070.50it/s]
#  87%|████████▋ | 439/503 [01:35<00:17,  3.59it/s]
# 2it [00:00, 5979.05it/s]
#  87%|████████▋ | 440/503 [01:36<00:19,  3.30it/s]
# 1it [00:00, 2657.99it/s]
#  88%|████████▊ | 441/503 [01:36<00:19,  3.13it/s]
# 2it [00:00, 5726.01it/s]
#  88%|████████▊ | 442/503 [01:36<00:17,  3.58it/s]
# 2it [00:00, 4301.85it/s]
#  88%|████████▊ | 443/503 [01:37<00:16,  3.64it/s]
# 1it [00:00, 3548.48it/s]
#  88%|████████▊ | 444/503 [01:37<00:15,  3.73it/s]
# 1it [00:00, 3141.80it/s]
#  88%|████████▊ | 445/503 [01:37<00:15,  3.72it/s]
# 4it [00:00, 7476.48it/s]
#  89%|████████▊ | 446/503 [01:37<00:15,  3.71it/s]
# 2it [00:00, 4931.57it/s]
#  89%|████████▉ | 447/503 [01:38<00:14,  3.94it/s]
# 2it [00:00, 5356.71it/s]
#  89%|████████▉ | 448/503 [01:38<00:12,  4.26it/s]
# 1it [00:00, 2939.25it/s]
#  89%|████████▉ | 449/503 [01:38<00:12,  4.31it/s]
# 1it [00:00, 2976.79it/s]
#  89%|████████▉ | 450/503 [01:38<00:12,  4.22it/s]
# 1it [00:00, 2666.44it/s]
#  90%|████████▉ | 451/503 [01:38<00:11,  4.42it/s]
# 1it [00:00, 3415.56it/s]
#  90%|████████▉ | 452/503 [01:39<00:12,  4.06it/s]
# 3it [00:00, 5336.26it/s]
#  90%|█████████ | 453/503 [01:39<00:13,  3.60it/s]
# 1it [00:00, 3167.90it/s]
#  90%|█████████ | 454/503 [01:39<00:14,  3.34it/s]
# 1it [00:00, 3331.46it/s]
#  90%|█████████ | 455/503 [01:40<00:15,  3.17it/s]
# 1it [00:00, 2678.36it/s]
#  91%|█████████ | 456/503 [01:40<00:13,  3.59it/s]
# 1it [00:00, 2732.45it/s]
#  91%|█████████ | 457/503 [01:40<00:11,  3.86it/s]
# 2it [00:00, 4319.57it/s]
#  91%|█████████ | 458/503 [01:40<00:12,  3.74it/s]
# 1it [00:00, 3292.23it/s]
#  91%|█████████▏| 459/503 [01:41<00:11,  3.95it/s]
# 2it [00:00, 5769.33it/s]
#  91%|█████████▏| 460/503 [01:41<00:10,  4.17it/s]
# 1it [00:00, 2706.00it/s]
#  92%|█████████▏| 461/503 [01:41<00:09,  4.43it/s]
# 1it [00:00, 2621.44it/s]
#  92%|█████████▏| 462/503 [01:41<00:08,  4.60it/s]
# 4it [00:00, 8881.53it/s]
#  92%|█████████▏| 463/503 [01:42<00:08,  4.50it/s]
# 3it [00:00, 5538.25it/s]
#  92%|█████████▏| 464/503 [01:42<00:08,  4.50it/s]
# 1it [00:00, 3253.92it/s]
#  92%|█████████▏| 465/503 [01:42<00:08,  4.53it/s]
# 1it [00:00, 3566.59it/s]
#  93%|█████████▎| 466/503 [01:42<00:07,  4.85it/s]
# 1it [00:00, 3463.50it/s]
#  93%|█████████▎| 467/503 [01:42<00:07,  5.09it/s]
# 2it [00:00, 5339.66it/s]
#  93%|█████████▎| 468/503 [01:43<00:07,  4.89it/s]
# 1it [00:00, 2951.66it/s]
#  93%|█████████▎| 469/503 [01:43<00:06,  4.86it/s]
# 1it [00:00, 2608.40it/s]
#  93%|█████████▎| 470/503 [01:43<00:07,  4.60it/s]
# 2it [00:00, 3785.47it/s]
#  94%|█████████▎| 471/503 [01:43<00:07,  4.46it/s]
# 1it [00:00, 1880.85it/s]
#  94%|█████████▍| 472/503 [01:44<00:07,  4.16it/s]
# 2it [00:00, 5936.74it/s]
#  94%|█████████▍| 473/503 [01:44<00:07,  4.07it/s]
# 1it [00:00, 3650.40it/s]
#  94%|█████████▍| 474/503 [01:44<00:07,  4.08it/s]
# 1it [00:00, 3226.39it/s]
#  94%|█████████▍| 475/503 [01:44<00:06,  4.07it/s]
# 1it [00:00, 2993.79it/s]
#  95%|█████████▍| 476/503 [01:44<00:06,  4.35it/s]
# 1it [00:00, 3000.22it/s]
#  95%|█████████▍| 477/503 [01:45<00:05,  4.45it/s]
# 1it [00:00, 2163.13it/s]
#  95%|█████████▌| 478/503 [01:45<00:05,  4.78it/s]
# 1it [00:00, 3179.91it/s]
#  95%|█████████▌| 479/503 [01:45<00:04,  4.89it/s]
# 2it [00:00, 4221.75it/s]
#  95%|█████████▌| 480/503 [01:45<00:04,  4.80it/s]
# 2it [00:00, 4554.08it/s]
#  96%|█████████▌| 481/503 [01:45<00:04,  4.85it/s]
# 2it [00:00, 5729.92it/s]
#  96%|█████████▌| 482/503 [01:46<00:04,  4.93it/s]
# 2it [00:00, 5726.01it/s]
#  96%|█████████▌| 483/503 [01:46<00:04,  4.80it/s]
# 2it [00:00, 6013.34it/s]
#  96%|█████████▌| 484/503 [01:46<00:04,  4.59it/s]
# 2it [00:00, 4385.05it/s]
#  96%|█████████▋| 485/503 [01:46<00:03,  4.51it/s]
# 2it [00:00, 3081.78it/s]
#  97%|█████████▋| 486/503 [01:47<00:03,  4.49it/s]
# 3it [00:00, 7485.37it/s]
#  97%|█████████▋| 487/503 [01:47<00:03,  4.62it/s]
# 1it [00:00, 3175.10it/s]
#  97%|█████████▋| 488/503 [01:47<00:03,  4.65it/s]
# 3it [00:00, 5940.94it/s]
#  97%|█████████▋| 489/503 [01:47<00:03,  4.48it/s]
# 1it [00:00, 3554.49it/s]
#  97%|█████████▋| 490/503 [01:47<00:02,  4.61it/s]
# 2it [00:00, 5433.04it/s]
#  98%|█████████▊| 491/503 [01:48<00:02,  4.82it/s]
# 1it [00:00, 3751.61it/s]
#  98%|█████████▊| 492/503 [01:48<00:02,  5.02it/s]
# 4it [00:00, 7313.52it/s]
#  98%|█████████▊| 493/503 [01:48<00:01,  5.11it/s]
# 1it [00:00, 3647.22it/s]
#  98%|█████████▊| 494/503 [01:48<00:01,  5.33it/s]
# 1it [00:00, 3715.06it/s]
#  98%|█████████▊| 495/503 [01:48<00:01,  5.40it/s]
# 2it [00:00, 6074.30it/s]
#  99%|█████████▊| 496/503 [01:49<00:01,  5.29it/s]
# 1it [00:00, 3297.41it/s]
#  99%|█████████▉| 497/503 [01:49<00:01,  4.98it/s]
# 1it [00:00, 3148.88it/s]
#  99%|█████████▉| 498/503 [01:49<00:01,  4.91it/s]
# 1it [00:00, 2721.81it/s]
#  99%|█████████▉| 499/503 [01:49<00:00,  4.78it/s]
# 3it [00:00, 6482.70it/s]
#  99%|█████████▉| 500/503 [01:49<00:00,  5.09it/s]
# 1it [00:00, 2981.03it/s]
# 100%|█████████▉| 501/503 [01:50<00:00,  5.24it/s]
# 1it [00:00, 2859.10it/s]
# 100%|█████████▉| 502/503 [01:50<00:00,  4.92it/s]
# 1it [00:00, 3019.66it/s]
# 100%|██████████| 503/503 [01:50<00:00,  4.55it/s]
# Saving record file: ./data/records/train.record
#   0%|          | 0/111 [00:00<?, ?it/s]
# 1it [00:00, 1670.37it/s]
# Successful created record files
# train.record has been successful created
#   1%|          | 1/111 [00:00<00:29,  3.73it/s]
# 1it [00:00, 2859.10it/s]
#   2%|▏         | 2/111 [00:00<00:28,  3.86it/s]
# 1it [00:00, 2692.11it/s]
#   3%|▎         | 3/111 [00:00<00:26,  4.08it/s]
# 4it [00:00, 7674.85it/s]
#   4%|▎         | 4/111 [00:00<00:26,  3.97it/s]
# 4it [00:00, 8367.69it/s]
#   5%|▍         | 5/111 [00:01<00:26,  3.95it/s]
# 1it [00:00, 2585.88it/s]
#   5%|▌         | 6/111 [00:01<00:27,  3.78it/s]
# 2it [00:00, 4606.59it/s]
#   6%|▋         | 7/111 [00:01<00:24,  4.19it/s]
# 1it [00:00, 3226.39it/s]
#   7%|▋         | 8/111 [00:01<00:23,  4.42it/s]
# 1it [00:00, 2759.41it/s]
#   8%|▊         | 9/111 [00:02<00:22,  4.47it/s]
# 1it [00:00, 1992.54it/s]
#   9%|▉         | 10/111 [00:02<00:21,  4.70it/s]
# 4it [00:00, 8643.59it/s]
#  10%|▉         | 11/111 [00:02<00:20,  4.97it/s]
# 3it [00:00, 7349.83it/s]
#  11%|█         | 12/111 [00:02<00:19,  5.05it/s]
# 1it [00:00, 3281.93it/s]
#  12%|█▏        | 13/111 [00:02<00:19,  4.91it/s]
# 2it [00:00, 4662.93it/s]
#  13%|█▎        | 14/111 [00:03<00:20,  4.72it/s]
# 1it [00:00, 2505.56it/s]
#  14%|█▎        | 15/111 [00:03<00:20,  4.66it/s]
# 1it [00:00, 2690.38it/s]
#  14%|█▍        | 16/111 [00:03<00:20,  4.63it/s]
# 3it [00:00, 6348.59it/s]
#  15%|█▌        | 17/111 [00:03<00:20,  4.63it/s]
# 2it [00:00, 5223.29it/s]
#  16%|█▌        | 18/111 [00:03<00:19,  4.67it/s]
# 1it [00:00, 2866.92it/s]
#  17%|█▋        | 19/111 [00:04<00:19,  4.80it/s]
# 1it [00:00, 2707.75it/s]
#  18%|█▊        | 20/111 [00:04<00:18,  4.96it/s]
# 4it [00:00, 8608.11it/s]
#  19%|█▉        | 21/111 [00:04<00:17,  5.14it/s]
# 2it [00:00, 4466.78it/s]
#  20%|█▉        | 22/111 [00:04<00:17,  5.09it/s]
# 1it [00:00, 2685.21it/s]
#  21%|██        | 23/111 [00:04<00:17,  4.97it/s]
# 1it [00:00, 2805.55it/s]
#  22%|██▏       | 24/111 [00:05<00:17,  4.97it/s]
# 4it [00:00, 7785.25it/s]
#  23%|██▎       | 25/111 [00:05<00:16,  5.33it/s]
# 2it [00:00, 5757.45it/s]
#  23%|██▎       | 26/111 [00:05<00:15,  5.45it/s]
# 1it [00:00, 3236.35it/s]
#  24%|██▍       | 27/111 [00:05<00:16,  5.14it/s]
# 1it [00:00, 1691.93it/s]
#  25%|██▌       | 28/111 [00:06<00:19,  4.34it/s]
# 2it [00:00, 3804.36it/s]
#  26%|██▌       | 29/111 [00:06<00:19,  4.11it/s]
# 1it [00:00, 2070.24it/s]
#  27%|██▋       | 30/111 [00:06<00:22,  3.68it/s]
# 1it [00:00, 2082.57it/s]
#  28%|██▊       | 31/111 [00:07<00:23,  3.36it/s]
# 5it [00:00, 3654.85it/s]
#  29%|██▉       | 32/111 [00:07<00:26,  2.99it/s]
# 2it [00:00, 2428.66it/s]
#  30%|██▉       | 33/111 [00:07<00:25,  3.05it/s]
# 1it [00:00, 2223.92it/s]
#  31%|███       | 34/111 [00:08<00:24,  3.13it/s]
# 2it [00:00, 3344.74it/s]
#  32%|███▏      | 35/111 [00:08<00:24,  3.12it/s]
# 2it [00:00, 2601.12it/s]
#  32%|███▏      | 36/111 [00:08<00:23,  3.19it/s]
# 1it [00:00, 1476.87it/s]
#  33%|███▎      | 37/111 [00:08<00:22,  3.22it/s]
# 1it [00:00, 1693.30it/s]
#  34%|███▍      | 38/111 [00:09<00:22,  3.28it/s]
# 1it [00:00, 1633.93it/s]
#  35%|███▌      | 39/111 [00:09<00:22,  3.24it/s]
# 2it [00:00, 5349.88it/s]
#  36%|███▌      | 40/111 [00:09<00:22,  3.13it/s]
# 1it [00:00, 3088.59it/s]
#  37%|███▋      | 41/111 [00:10<00:20,  3.34it/s]
# 2it [00:00, 4681.14it/s]
#  38%|███▊      | 42/111 [00:10<00:19,  3.51it/s]
# 1it [00:00, 1812.58it/s]
#  39%|███▊      | 43/111 [00:10<00:18,  3.66it/s]
# 2it [00:00, 4330.72it/s]
#  40%|███▉      | 44/111 [00:10<00:18,  3.63it/s]
# 1it [00:00, 3258.98it/s]
#  41%|████      | 45/111 [00:11<00:17,  3.71it/s]
# 1it [00:00, 2880.70it/s]
#  41%|████▏     | 46/111 [00:11<00:16,  3.86it/s]
# 1it [00:00, 3216.49it/s]
#  42%|████▏     | 47/111 [00:11<00:15,  4.06it/s]
# 1it [00:00, 2943.37it/s]
#  43%|████▎     | 48/111 [00:11<00:14,  4.38it/s]
# 2it [00:00, 4070.16it/s]
#  44%|████▍     | 49/111 [00:12<00:13,  4.47it/s]
# 1it [00:00, 1726.05it/s]
#  45%|████▌     | 50/111 [00:12<00:13,  4.57it/s]
# 3it [00:00, 5516.40it/s]
#  46%|████▌     | 51/111 [00:12<00:12,  4.65it/s]
# 1it [00:00, 3039.35it/s]
#  47%|████▋     | 52/111 [00:12<00:12,  4.55it/s]
# 1it [00:00, 2411.91it/s]
#  48%|████▊     | 53/111 [00:12<00:12,  4.60it/s]
# 2it [00:00, 5130.65it/s]
#  49%|████▊     | 54/111 [00:13<00:12,  4.62it/s]
# 1it [00:00, 3165.51it/s]
#  50%|████▉     | 55/111 [00:13<00:12,  4.44it/s]
# 2it [00:00, 3442.19it/s]
#  50%|█████     | 56/111 [00:13<00:12,  4.46it/s]
# 1it [00:00, 3248.88it/s]
#  51%|█████▏    | 57/111 [00:13<00:12,  4.37it/s]
# 1it [00:00, 3246.37it/s]
#  52%|█████▏    | 58/111 [00:14<00:11,  4.43it/s]
# 1it [00:00, 2711.25it/s]
#  53%|█████▎    | 59/111 [00:14<00:11,  4.43it/s]
# 1it [00:00, 2332.76it/s]
#  54%|█████▍    | 60/111 [00:14<00:11,  4.52it/s]
# 1it [00:00, 2106.63it/s]
#  55%|█████▍    | 61/111 [00:14<00:10,  4.56it/s]
# 1it [00:00, 2757.60it/s]
#  56%|█████▌    | 62/111 [00:14<00:10,  4.50it/s]
# 2it [00:00, 4720.66it/s]
#  57%|█████▋    | 63/111 [00:15<00:10,  4.64it/s]
# 4it [00:00, 7869.24it/s]
#  58%|█████▊    | 64/111 [00:15<00:10,  4.49it/s]
# 1it [00:00, 1290.16it/s]
#  59%|█████▊    | 65/111 [00:15<00:10,  4.59it/s]
# 1it [00:00, 2197.12it/s]
#  59%|█████▉    | 66/111 [00:15<00:09,  4.61it/s]
# 1it [00:00, 2435.72it/s]
#  60%|██████    | 67/111 [00:16<00:09,  4.55it/s]
# 1it [00:00, 3068.25it/s]
#  61%|██████▏   | 68/111 [00:16<00:08,  4.78it/s]
# 2it [00:00, 4969.55it/s]
#  62%|██████▏   | 69/111 [00:16<00:08,  4.86it/s]
# 1it [00:00, 2498.10it/s]
#  63%|██████▎   | 70/111 [00:16<00:08,  4.79it/s]
# 2it [00:00, 5555.37it/s]
#  64%|██████▍   | 71/111 [00:16<00:08,  4.56it/s]
# 1it [00:00, 2949.58it/s]
#  65%|██████▍   | 72/111 [00:17<00:08,  4.61it/s]
# 1it [00:00, 2832.08it/s]
#  66%|██████▌   | 73/111 [00:17<00:08,  4.63it/s]
# 2it [00:00, 4040.76it/s]
#  67%|██████▋   | 74/111 [00:17<00:07,  4.77it/s]
# 3it [00:00, 7202.58it/s]
#  68%|██████▊   | 75/111 [00:17<00:07,  4.76it/s]
# 1it [00:00, 3320.91it/s]
#  68%|██████▊   | 76/111 [00:17<00:07,  4.94it/s]
# 2it [00:00, 5559.05it/s]
#  69%|██████▉   | 77/111 [00:18<00:06,  5.17it/s]
# 2it [00:00, 4348.68it/s]
#  70%|███████   | 78/111 [00:18<00:06,  4.93it/s]
# 1it [00:00, 2365.65it/s]
#  71%|███████   | 79/111 [00:18<00:06,  5.04it/s]
# 1it [00:00, 3415.56it/s]
#  72%|███████▏  | 80/111 [00:18<00:05,  5.19it/s]
# 1it [00:00, 2637.93it/s]
#  73%|███████▎  | 81/111 [00:18<00:05,  5.11it/s]
# 1it [00:00, 2678.36it/s]
#  74%|███████▍  | 82/111 [00:19<00:05,  5.00it/s]
# 2it [00:00, 4447.83it/s]
#  75%|███████▍  | 83/111 [00:19<00:05,  5.10it/s]
# 1it [00:00, 3214.03it/s]
#  76%|███████▌  | 84/111 [00:19<00:05,  5.06it/s]
# 2it [00:00, 2972.58it/s]
#  77%|███████▋  | 85/111 [00:19<00:05,  5.09it/s]
# 1it [00:00, 3199.32it/s]
#  77%|███████▋  | 86/111 [00:19<00:05,  4.86it/s]
# 2it [00:00, 4192.21it/s]
#  78%|███████▊  | 87/111 [00:20<00:04,  4.86it/s]
# 2it [00:00, 5890.88it/s]
#  79%|███████▉  | 88/111 [00:20<00:04,  4.96it/s]
# 2it [00:00, 4350.94it/s]
#  80%|████████  | 89/111 [00:20<00:04,  4.75it/s]
# 2it [00:00, 4301.85it/s]
#  81%|████████  | 90/111 [00:20<00:04,  4.91it/s]
# 2it [00:00, 4549.14it/s]
#  82%|████████▏ | 91/111 [00:20<00:04,  4.96it/s]
# 2it [00:00, 5026.13it/s]
#  83%|████████▎ | 92/111 [00:21<00:04,  4.57it/s]
# 2it [00:00, 4657.75it/s]
#  84%|████████▍ | 93/111 [00:21<00:03,  4.66it/s]
# 2it [00:00, 5322.72it/s]
#  85%|████████▍ | 94/111 [00:21<00:03,  4.70it/s]
# 2it [00:00, 3592.55it/s]
#  86%|████████▌ | 95/111 [00:21<00:04,  3.97it/s]
# 2it [00:00, 4429.04it/s]
#  86%|████████▋ | 96/111 [00:22<00:04,  3.72it/s]
# 1it [00:00, 3163.13it/s]
#  87%|████████▋ | 97/111 [00:22<00:03,  3.94it/s]
# 2it [00:00, 5299.18it/s]
#  88%|████████▊ | 98/111 [00:22<00:03,  3.95it/s]
# 2it [00:00, 5029.14it/s]
#  89%|████████▉ | 99/111 [00:22<00:03,  3.67it/s]
# 2it [00:00, 5233.07it/s]
#  90%|█████████ | 100/111 [00:23<00:02,  4.03it/s]
# 2it [00:00, 4758.14it/s]
#  91%|█████████ | 101/111 [00:23<00:02,  4.34it/s]
# 2it [00:00, 4405.78it/s]
#  92%|█████████▏| 102/111 [00:23<00:01,  4.54it/s]
# 2it [00:00, 5882.61it/s]
#  93%|█████████▎| 103/111 [00:23<00:01,  4.37it/s]
# 2it [00:00, 4696.87it/s]
#  94%|█████████▎| 104/111 [00:24<00:01,  4.51it/s]
# 1it [00:00, 2828.26it/s]
#  95%|█████████▍| 105/111 [00:24<00:01,  4.25it/s]
# 3it [00:00, 6971.14it/s]
#  95%|█████████▌| 106/111 [00:24<00:01,  4.36it/s]
# 2it [00:00, 4408.10it/s]
#  96%|█████████▋| 107/111 [00:24<00:00,  4.50it/s]
# 1it [00:00, 3079.52it/s]
#  97%|█████████▋| 108/111 [00:24<00:00,  4.42it/s]
# 1it [00:00, 2874.78it/s]
#  98%|█████████▊| 109/111 [00:25<00:00,  4.56it/s]
# 2it [00:00, 5305.89it/s]
#  99%|█████████▉| 110/111 [00:25<00:00,  4.90it/s]
# 1it [00:00, 3320.91it/s]
# 100%|██████████| 111/111 [00:25<00:00,  4.36it/s]
# Saving record file: ./data/records/val.record
# Successful created record files
# val.record has been successful created

# %% [markdown]
# ## Create pbtxt

# %%
import numpy as np

input_file = './data/gtsdb.label'
output_file = './data/gtsdb.pbtxt'


with open(output_file, 'w+') as output:
    with open(input_file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            if not line.split():
                continue
            line = line.strip()
            number, name = line.split(' ', 1)
            output_str = "item { \n" + \
                        "  id: " + number + "\n" + \
                        "  name: \'" + name + '\'' + \
                        "\n}\n\n"

            output.write(output_str)
            
print("Create success.")
# Out:
# Create success.

# %% [markdown]
# ## Transfer ppm into png
# ppm has to be transfered into png format for tensorflow object detection API decoder reason.

# %%
#coding=utf-8 
from PIL import Image 
import os
import tqdm

data_dir = './data'
#train_img_dir = os.path.join(data_dir, 'TrainIJCNN2013')
train_img_dir = os.path.join(data_dir, 'FullIJCNN2013')
png_img_dir = os.path.join(data_dir, 'png_FullIJCNN2013')


if os.path.exists(png_img_dir):
    shutil.rmtree(png_img_dir)
os.makedirs(png_img_dir) 

for img_name in tqdm(os.listdir(train_img_dir)):
#for img_name in ["00000.ppm","00001.ppm","00002.ppm"]:
    if img_name[-3:] == "ppm":
        img_path = os.path.join(train_img_dir, img_name)
        img = Image.open(img_path)
        png_path = os.path.join(png_img_dir, img_name[:-3]+'png')
        #print(png_path)
        img.save(png_path)
        #img.show()
# Out:
# ./data/png_FullIJCNN2013/00267.png
# ./data/png_FullIJCNN2013/00460.png
# ./data/png_FullIJCNN2013/00114.png
# ./data/png_FullIJCNN2013/00873.png
# ./data/png_FullIJCNN2013/00894.png
# ./data/png_FullIJCNN2013/00072.png
# ./data/png_FullIJCNN2013/00578.png
# ./data/png_FullIJCNN2013/00555.png
# ./data/png_FullIJCNN2013/00704.png
# ./data/png_FullIJCNN2013/00866.png
# ./data/png_FullIJCNN2013/00452.png
# ./data/png_FullIJCNN2013/00605.png
# ./data/png_FullIJCNN2013/00095.png
# ./data/png_FullIJCNN2013/00847.png
# ./data/png_FullIJCNN2013/00054.png
# ./data/png_FullIJCNN2013/00835.png
# ./data/png_FullIJCNN2013/00832.png
# ./data/png_FullIJCNN2013/00103.png
# ./data/png_FullIJCNN2013/00283.png
# ./data/png_FullIJCNN2013/00476.png
# ./data/png_FullIJCNN2013/00343.png
# ./data/png_FullIJCNN2013/00406.png
# ./data/png_FullIJCNN2013/00244.png
# ./data/png_FullIJCNN2013/00501.png
# ./data/png_FullIJCNN2013/00892.png
# ./data/png_FullIJCNN2013/00379.png
# ./data/png_FullIJCNN2013/00466.png
# ./data/png_FullIJCNN2013/00748.png
# ./data/png_FullIJCNN2013/00357.png
# ./data/png_FullIJCNN2013/00590.png
# ./data/png_FullIJCNN2013/00853.png
# ./data/png_FullIJCNN2013/00418.png
# ./data/png_FullIJCNN2013/00773.png
# ./data/png_FullIJCNN2013/00472.png
# ./data/png_FullIJCNN2013/00075.png
# ./data/png_FullIJCNN2013/00222.png
# ./data/png_FullIJCNN2013/00378.png
# ./data/png_FullIJCNN2013/00214.png
# ./data/png_FullIJCNN2013/00596.png
# ./data/png_FullIJCNN2013/00836.png
# ./data/png_FullIJCNN2013/00524.png
# ./data/png_FullIJCNN2013/00800.png
# ./data/png_FullIJCNN2013/00139.png
# ./data/png_FullIJCNN2013/00089.png
# ./data/png_FullIJCNN2013/00316.png
# ./data/png_FullIJCNN2013/00765.png
# ./data/png_FullIJCNN2013/00700.png
# ./data/png_FullIJCNN2013/00666.png
# ./data/png_FullIJCNN2013/00517.png
# ./data/png_FullIJCNN2013/00263.png
# ./data/png_FullIJCNN2013/00271.png
# ./data/png_FullIJCNN2013/00129.png
# ./data/png_FullIJCNN2013/00645.png
# ./data/png_FullIJCNN2013/00734.png
# ./data/png_FullIJCNN2013/00387.png
# ./data/png_FullIJCNN2013/00397.png
# ./data/png_FullIJCNN2013/00199.png
# ./data/png_FullIJCNN2013/00405.png
# ./data/png_FullIJCNN2013/00341.png
# ./data/png_FullIJCNN2013/00436.png
# ./data/png_FullIJCNN2013/00306.png
# ./data/png_FullIJCNN2013/00570.png
# ./data/png_FullIJCNN2013/00120.png
# ./data/png_FullIJCNN2013/00291.png
# ./data/png_FullIJCNN2013/00568.png
# ./data/png_FullIJCNN2013/00308.png
# ./data/png_FullIJCNN2013/00088.png
# ./data/png_FullIJCNN2013/00230.png
# ./data/png_FullIJCNN2013/00313.png
# ./data/png_FullIJCNN2013/00752.png
# ./data/png_FullIJCNN2013/00652.png
# ./data/png_FullIJCNN2013/00569.png
# ./data/png_FullIJCNN2013/00035.png
# ./data/png_FullIJCNN2013/00073.png
# ./data/png_FullIJCNN2013/00126.png
# ./data/png_FullIJCNN2013/00383.png
# ./data/png_FullIJCNN2013/00038.png
# ./data/png_FullIJCNN2013/00668.png
# ./data/png_FullIJCNN2013/00252.png
# ./data/png_FullIJCNN2013/00872.png
# ./data/png_FullIJCNN2013/00009.png
# ./data/png_FullIJCNN2013/00010.png
# ./data/png_FullIJCNN2013/00509.png
# ./data/png_FullIJCNN2013/00186.png
# ./data/png_FullIJCNN2013/00259.png
# ./data/png_FullIJCNN2013/00346.png
# ./data/png_FullIJCNN2013/00660.png
# ./data/png_FullIJCNN2013/00057.png
# ./data/png_FullIJCNN2013/00164.png
# ./data/png_FullIJCNN2013/00714.png
# ./data/png_FullIJCNN2013/00849.png
# ./data/png_FullIJCNN2013/00797.png
# ./data/png_FullIJCNN2013/00040.png
# ./data/png_FullIJCNN2013/00741.png
# ./data/png_FullIJCNN2013/00463.png
# ./data/png_FullIJCNN2013/00039.png
# ./data/png_FullIJCNN2013/00695.png
# ./data/png_FullIJCNN2013/00633.png
# ./data/png_FullIJCNN2013/00615.png
# ./data/png_FullIJCNN2013/00689.png
# ./data/png_FullIJCNN2013/00102.png
# ./data/png_FullIJCNN2013/00005.png
# ./data/png_FullIJCNN2013/00776.png
# ./data/png_FullIJCNN2013/00180.png
# ./data/png_FullIJCNN2013/00450.png
# ./data/png_FullIJCNN2013/00796.png
# ./data/png_FullIJCNN2013/00350.png
# ./data/png_FullIJCNN2013/00575.png
# ./data/png_FullIJCNN2013/00042.png
# ./data/png_FullIJCNN2013/00410.png
# ./data/png_FullIJCNN2013/00248.png
# ./data/png_FullIJCNN2013/00712.png
# ./data/png_FullIJCNN2013/00411.png
# ./data/png_FullIJCNN2013/00052.png
# ./data/png_FullIJCNN2013/00019.png
# ./data/png_FullIJCNN2013/00487.png
# ./data/png_FullIJCNN2013/00078.png
# ./data/png_FullIJCNN2013/00384.png
# ./data/png_FullIJCNN2013/00033.png
# ./data/png_FullIJCNN2013/00107.png
# ./data/png_FullIJCNN2013/00786.png
# ./data/png_FullIJCNN2013/00826.png
# ./data/png_FullIJCNN2013/00251.png
# ./data/png_FullIJCNN2013/00574.png
# ./data/png_FullIJCNN2013/00281.png
# ./data/png_FullIJCNN2013/00759.png
# ./data/png_FullIJCNN2013/00370.png
# ./data/png_FullIJCNN2013/00360.png
# ./data/png_FullIJCNN2013/00494.png
# ./data/png_FullIJCNN2013/00888.png
# ./data/png_FullIJCNN2013/00336.png
# ./data/png_FullIJCNN2013/00270.png
# ./data/png_FullIJCNN2013/00682.png
# ./data/png_FullIJCNN2013/00061.png
# ./data/png_FullIJCNN2013/00520.png
# ./data/png_FullIJCNN2013/00226.png
# ./data/png_FullIJCNN2013/00785.png
# ./data/png_FullIJCNN2013/00296.png
# ./data/png_FullIJCNN2013/00025.png
# ./data/png_FullIJCNN2013/00614.png
# ./data/png_FullIJCNN2013/00644.png
# ./data/png_FullIJCNN2013/00754.png
# ./data/png_FullIJCNN2013/00653.png
# ./data/png_FullIJCNN2013/00477.png
# ./data/png_FullIJCNN2013/00045.png
# ./data/png_FullIJCNN2013/00449.png
# ./data/png_FullIJCNN2013/00144.png
# ./data/png_FullIJCNN2013/00443.png
# ./data/png_FullIJCNN2013/00285.png
# ./data/png_FullIJCNN2013/00011.png
# ./data/png_FullIJCNN2013/00803.png
# ./data/png_FullIJCNN2013/00606.png
# ./data/png_FullIJCNN2013/00890.png
# ./data/png_FullIJCNN2013/00761.png
# ./data/png_FullIJCNN2013/00421.png
# ./data/png_FullIJCNN2013/00674.png
# ./data/png_FullIJCNN2013/00183.png
# ./data/png_FullIJCNN2013/00560.png
# ./data/png_FullIJCNN2013/00852.png
# ./data/png_FullIJCNN2013/00368.png
# ./data/png_FullIJCNN2013/00172.png
# ./data/png_FullIJCNN2013/00798.png
# ./data/png_FullIJCNN2013/00190.png
# ./data/png_FullIJCNN2013/00254.png
# ./data/png_FullIJCNN2013/00877.png
# ./data/png_FullIJCNN2013/00091.png
# ./data/png_FullIJCNN2013/00839.png
# ./data/png_FullIJCNN2013/00726.png
# ./data/png_FullIJCNN2013/00340.png
# ./data/png_FullIJCNN2013/00330.png
# ./data/png_FullIJCNN2013/00593.png
# ./data/png_FullIJCNN2013/00587.png
# ./data/png_FullIJCNN2013/00339.png
# ./data/png_FullIJCNN2013/00189.png
# ./data/png_FullIJCNN2013/00203.png
# ./data/png_FullIJCNN2013/00620.png
# ./data/png_FullIJCNN2013/00525.png
# ./data/png_FullIJCNN2013/00805.png
# ./data/png_FullIJCNN2013/00782.png
# ./data/png_FullIJCNN2013/00471.png
# ./data/png_FullIJCNN2013/00558.png
# ./data/png_FullIJCNN2013/00423.png
# ./data/png_FullIJCNN2013/00305.png
# ./data/png_FullIJCNN2013/00497.png
# ./data/png_FullIJCNN2013/00706.png
# ./data/png_FullIJCNN2013/00050.png
# ./data/png_FullIJCNN2013/00076.png
# ./data/png_FullIJCNN2013/00394.png
# ./data/png_FullIJCNN2013/00583.png
# ./data/png_FullIJCNN2013/00206.png
# ./data/png_FullIJCNN2013/00003.png
# ./data/png_FullIJCNN2013/00564.png
# ./data/png_FullIJCNN2013/00562.png
# ./data/png_FullIJCNN2013/00701.png
# ./data/png_FullIJCNN2013/00113.png
# ./data/png_FullIJCNN2013/00504.png
# ./data/png_FullIJCNN2013/00108.png
# ./data/png_FullIJCNN2013/00519.png
# ./data/png_FullIJCNN2013/00535.png
# ./data/png_FullIJCNN2013/00654.png
# ./data/png_FullIJCNN2013/00869.png
# ./data/png_FullIJCNN2013/00349.png
# ./data/png_FullIJCNN2013/00274.png
# ./data/png_FullIJCNN2013/00470.png
# ./data/png_FullIJCNN2013/00196.png
# ./data/png_FullIJCNN2013/00492.png
# ./data/png_FullIJCNN2013/00205.png
# ./data/png_FullIJCNN2013/00013.png
# ./data/png_FullIJCNN2013/00507.png
# ./data/png_FullIJCNN2013/00021.png
# ./data/png_FullIJCNN2013/00432.png
# ./data/png_FullIJCNN2013/00149.png
# ./data/png_FullIJCNN2013/00891.png
# ./data/png_FullIJCNN2013/00616.png
# ./data/png_FullIJCNN2013/00408.png
# ./data/png_FullIJCNN2013/00096.png
# ./data/png_FullIJCNN2013/00880.png
# ./data/png_FullIJCNN2013/00369.png
# ./data/png_FullIJCNN2013/00802.png
# ./data/png_FullIJCNN2013/00505.png
# ./data/png_FullIJCNN2013/00775.png
# ./data/png_FullIJCNN2013/00898.png
# ./data/png_FullIJCNN2013/00224.png
# ./data/png_FullIJCNN2013/00529.png
# ./data/png_FullIJCNN2013/00886.png
# ./data/png_FullIJCNN2013/00160.png
# ./data/png_FullIJCNN2013/00629.png
# ./data/png_FullIJCNN2013/00572.png
# ./data/png_FullIJCNN2013/00844.png
# ./data/png_FullIJCNN2013/00634.png
# ./data/png_FullIJCNN2013/00613.png
# ./data/png_FullIJCNN2013/00827.png
# ./data/png_FullIJCNN2013/00319.png
# ./data/png_FullIJCNN2013/00217.png
# ./data/png_FullIJCNN2013/00491.png
# ./data/png_FullIJCNN2013/00696.png
# ./data/png_FullIJCNN2013/00819.png
# ./data/png_FullIJCNN2013/00779.png
# ./data/png_FullIJCNN2013/00171.png
# ./data/png_FullIJCNN2013/00791.png
# ./data/png_FullIJCNN2013/00028.png
# ./data/png_FullIJCNN2013/00545.png
# ./data/png_FullIJCNN2013/00480.png
# ./data/png_FullIJCNN2013/00899.png
# ./data/png_FullIJCNN2013/00373.png
# ./data/png_FullIJCNN2013/00017.png
# ./data/png_FullIJCNN2013/00246.png
# ./data/png_FullIJCNN2013/00390.png
# ./data/png_FullIJCNN2013/00459.png
# ./data/png_FullIJCNN2013/00473.png
# ./data/png_FullIJCNN2013/00208.png
# ./data/png_FullIJCNN2013/00713.png
# ./data/png_FullIJCNN2013/00220.png
# ./data/png_FullIJCNN2013/00101.png
# ./data/png_FullIJCNN2013/00324.png
# ./data/png_FullIJCNN2013/00375.png
# ./data/png_FullIJCNN2013/00489.png
# ./data/png_FullIJCNN2013/00161.png
# ./data/png_FullIJCNN2013/00065.png
# ./data/png_FullIJCNN2013/00015.png
# ./data/png_FullIJCNN2013/00824.png
# ./data/png_FullIJCNN2013/00231.png
# ./data/png_FullIJCNN2013/00290.png
# ./data/png_FullIJCNN2013/00071.png
# ./data/png_FullIJCNN2013/00185.png
# ./data/png_FullIJCNN2013/00514.png
# ./data/png_FullIJCNN2013/00112.png
# ./data/png_FullIJCNN2013/00685.png
# ./data/png_FullIJCNN2013/00781.png
# ./data/png_FullIJCNN2013/00619.png
# ./data/png_FullIJCNN2013/00637.png
# ./data/png_FullIJCNN2013/00556.png
# ./data/png_FullIJCNN2013/00325.png
# ./data/png_FullIJCNN2013/00004.png
# ./data/png_FullIJCNN2013/00337.png
# ./data/png_FullIJCNN2013/00238.png
# ./data/png_FullIJCNN2013/00151.png
# ./data/png_FullIJCNN2013/00158.png
# ./data/png_FullIJCNN2013/00760.png
# ./data/png_FullIJCNN2013/00725.png
# ./data/png_FullIJCNN2013/00094.png
# ./data/png_FullIJCNN2013/00441.png
# ./data/png_FullIJCNN2013/00597.png
# ./data/png_FullIJCNN2013/00766.png
# ./data/png_FullIJCNN2013/00865.png
# ./data/png_FullIJCNN2013/00100.png
# ./data/png_FullIJCNN2013/00818.png
# ./data/png_FullIJCNN2013/00433.png
# ./data/png_FullIJCNN2013/00506.png
# ./data/png_FullIJCNN2013/00737.png
# ./data/png_FullIJCNN2013/00177.png
# ./data/png_FullIJCNN2013/00897.png
# ./data/png_FullIJCNN2013/00764.png
# ./data/png_FullIJCNN2013/00219.png
# ./data/png_FullIJCNN2013/00667.png
# ./data/png_FullIJCNN2013/00777.png
# ./data/png_FullIJCNN2013/00221.png
# ./data/png_FullIJCNN2013/00474.png
# ./data/png_FullIJCNN2013/00554.png
# ./data/png_FullIJCNN2013/00425.png
# ./data/png_FullIJCNN2013/00481.png
# ./data/png_FullIJCNN2013/00751.png
# ./data/png_FullIJCNN2013/00772.png
# ./data/png_FullIJCNN2013/00268.png
# ./data/png_FullIJCNN2013/00194.png
# ./data/png_FullIJCNN2013/00585.png
# ./data/png_FullIJCNN2013/00841.png
# ./data/png_FullIJCNN2013/00738.png
# ./data/png_FullIJCNN2013/00232.png
# ./data/png_FullIJCNN2013/00363.png
# ./data/png_FullIJCNN2013/00814.png
# ./data/png_FullIJCNN2013/00016.png
# ./data/png_FullIJCNN2013/00137.png
# ./data/png_FullIJCNN2013/00249.png
# ./data/png_FullIJCNN2013/00727.png
# ./data/png_FullIJCNN2013/00098.png
# ./data/png_FullIJCNN2013/00650.png
# ./data/png_FullIJCNN2013/00286.png
# ./data/png_FullIJCNN2013/00609.png
# ./data/png_FullIJCNN2013/00409.png
# ./data/png_FullIJCNN2013/00086.png
# ./data/png_FullIJCNN2013/00871.png
# ./data/png_FullIJCNN2013/00292.png
# ./data/png_FullIJCNN2013/00288.png
# ./data/png_FullIJCNN2013/00641.png
# ./data/png_FullIJCNN2013/00128.png
# ./data/png_FullIJCNN2013/00736.png
# ./data/png_FullIJCNN2013/00212.png
# ./data/png_FullIJCNN2013/00647.png
# ./data/png_FullIJCNN2013/00563.png
# ./data/png_FullIJCNN2013/00064.png
# ./data/png_FullIJCNN2013/00258.png
# ./data/png_FullIJCNN2013/00030.png
# ./data/png_FullIJCNN2013/00051.png
# ./data/png_FullIJCNN2013/00698.png
# ./data/png_FullIJCNN2013/00307.png
# ./data/png_FullIJCNN2013/00381.png
# ./data/png_FullIJCNN2013/00125.png
# ./data/png_FullIJCNN2013/00104.png
# ./data/png_FullIJCNN2013/00778.png
# ./data/png_FullIJCNN2013/00188.png
# ./data/png_FullIJCNN2013/00034.png
# ./data/png_FullIJCNN2013/00036.png
# ./data/png_FullIJCNN2013/00599.png
# ./data/png_FullIJCNN2013/00681.png
# ./data/png_FullIJCNN2013/00747.png
# ./data/png_FullIJCNN2013/00703.png
# ./data/png_FullIJCNN2013/00769.png
# ./data/png_FullIJCNN2013/00780.png
# ./data/png_FullIJCNN2013/00885.png
# ./data/png_FullIJCNN2013/00070.png
# ./data/png_FullIJCNN2013/00377.png
# ./data/png_FullIJCNN2013/00044.png
# ./data/png_FullIJCNN2013/00402.png
# ./data/png_FullIJCNN2013/00309.png
# ./data/png_FullIJCNN2013/00825.png
# ./data/png_FullIJCNN2013/00240.png
# ./data/png_FullIJCNN2013/00356.png
# ./data/png_FullIJCNN2013/00731.png
# ./data/png_FullIJCNN2013/00876.png
# ./data/png_FullIJCNN2013/00592.png
# ./data/png_FullIJCNN2013/00538.png
# ./data/png_FullIJCNN2013/00626.png
# ./data/png_FullIJCNN2013/00878.png
# ./data/png_FullIJCNN2013/00275.png
# ./data/png_FullIJCNN2013/00456.png
# ./data/png_FullIJCNN2013/00320.png
# ./data/png_FullIJCNN2013/00874.png
# ./data/png_FullIJCNN2013/00823.png
# ./data/png_FullIJCNN2013/00611.png
# ./data/png_FullIJCNN2013/00549.png
# ./data/png_FullIJCNN2013/00744.png
# ./data/png_FullIJCNN2013/00420.png
# ./data/png_FullIJCNN2013/00728.png
# ./data/png_FullIJCNN2013/00233.png
# ./data/png_FullIJCNN2013/00889.png
# ./data/png_FullIJCNN2013/00165.png
# ./data/png_FullIJCNN2013/00464.png
# ./data/png_FullIJCNN2013/00211.png
# ./data/png_FullIJCNN2013/00686.png
# ./data/png_FullIJCNN2013/00601.png
# ./data/png_FullIJCNN2013/00679.png
# ./data/png_FullIJCNN2013/00810.png
# ./data/png_FullIJCNN2013/00147.png
# ./data/png_FullIJCNN2013/00235.png
# ./data/png_FullIJCNN2013/00142.png
# ./data/png_FullIJCNN2013/00037.png
# ./data/png_FullIJCNN2013/00533.png
# ./data/png_FullIJCNN2013/00115.png
# ./data/png_FullIJCNN2013/00684.png
# ./data/png_FullIJCNN2013/00461.png
# ./data/png_FullIJCNN2013/00327.png
# ./data/png_FullIJCNN2013/00816.png
# ./data/png_FullIJCNN2013/00388.png
# ./data/png_FullIJCNN2013/00812.png
# ./data/png_FullIJCNN2013/00295.png
# ./data/png_FullIJCNN2013/00121.png
# ./data/png_FullIJCNN2013/00134.png
# ./data/png_FullIJCNN2013/00193.png
# ./data/png_FullIJCNN2013/00541.png
# ./data/png_FullIJCNN2013/00884.png
# ./data/png_FullIJCNN2013/00014.png
# ./data/png_FullIJCNN2013/00589.png
# ./data/png_FullIJCNN2013/00676.png
# ./data/png_FullIJCNN2013/00328.png
# ./data/png_FullIJCNN2013/00338.png
# ./data/png_FullIJCNN2013/00659.png
# ./data/png_FullIJCNN2013/00499.png
# ./data/png_FullIJCNN2013/00484.png
# ./data/png_FullIJCNN2013/00649.png
# ./data/png_FullIJCNN2013/00166.png
# ./data/png_FullIJCNN2013/00434.png
# ./data/png_FullIJCNN2013/00651.png
# ./data/png_FullIJCNN2013/00344.png
# ./data/png_FullIJCNN2013/00787.png
# ./data/png_FullIJCNN2013/00049.png
# ./data/png_FullIJCNN2013/00770.png
# ./data/png_FullIJCNN2013/00355.png
# ./data/png_FullIJCNN2013/00415.png
# ./data/png_FullIJCNN2013/00437.png
# ./data/png_FullIJCNN2013/00066.png
# ./data/png_FullIJCNN2013/00858.png
# ./data/png_FullIJCNN2013/00008.png
# ./data/png_FullIJCNN2013/00143.png
# ./data/png_FullIJCNN2013/00250.png
# ./data/png_FullIJCNN2013/00539.png
# ./data/png_FullIJCNN2013/00646.png
# ./data/png_FullIJCNN2013/00670.png
# ./data/png_FullIJCNN2013/00655.png
# ./data/png_FullIJCNN2013/00468.png
# ./data/png_FullIJCNN2013/00053.png
# ./data/png_FullIJCNN2013/00391.png
# ./data/png_FullIJCNN2013/00393.png
# ./data/png_FullIJCNN2013/00416.png
# ./data/png_FullIJCNN2013/00733.png
# ./data/png_FullIJCNN2013/00657.png
# ./data/png_FullIJCNN2013/00366.png
# ./data/png_FullIJCNN2013/00740.png
# ./data/png_FullIJCNN2013/00482.png
# ./data/png_FullIJCNN2013/00485.png
# ./data/png_FullIJCNN2013/00462.png
# ./data/png_FullIJCNN2013/00195.png
# ./data/png_FullIJCNN2013/00435.png
# ./data/png_FullIJCNN2013/00032.png
# ./data/png_FullIJCNN2013/00838.png
# ./data/png_FullIJCNN2013/00813.png
# ./data/png_FullIJCNN2013/00717.png
# ./data/png_FullIJCNN2013/00763.png
# ./data/png_FullIJCNN2013/00788.png
# ./data/png_FullIJCNN2013/00204.png
# ./data/png_FullIJCNN2013/00848.png
# ./data/png_FullIJCNN2013/00631.png
# ./data/png_FullIJCNN2013/00857.png
# ./data/png_FullIJCNN2013/00656.png
# ./data/png_FullIJCNN2013/00084.png
# ./data/png_FullIJCNN2013/00692.png
# ./data/png_FullIJCNN2013/00493.png
# ./data/png_FullIJCNN2013/00793.png
# ./data/png_FullIJCNN2013/00753.png
# ./data/png_FullIJCNN2013/00496.png
# ./data/png_FullIJCNN2013/00174.png
# ./data/png_FullIJCNN2013/00548.png
# ./data/png_FullIJCNN2013/00389.png
# ./data/png_FullIJCNN2013/00550.png
# ./data/png_FullIJCNN2013/00048.png
# ./data/png_FullIJCNN2013/00424.png
# ./data/png_FullIJCNN2013/00431.png
# ./data/png_FullIJCNN2013/00273.png
# ./data/png_FullIJCNN2013/00345.png
# ./data/png_FullIJCNN2013/00707.png
# ./data/png_FullIJCNN2013/00757.png
# ./data/png_FullIJCNN2013/00783.png
# ./data/png_FullIJCNN2013/00834.png
# ./data/png_FullIJCNN2013/00498.png
# ./data/png_FullIJCNN2013/00118.png
# ./data/png_FullIJCNN2013/00266.png
# ./data/png_FullIJCNN2013/00859.png
# ./data/png_FullIJCNN2013/00882.png
# ./data/png_FullIJCNN2013/00202.png
# ./data/png_FullIJCNN2013/00475.png
# ./data/png_FullIJCNN2013/00359.png
# ./data/png_FullIJCNN2013/00179.png
# ./data/png_FullIJCNN2013/00301.png
# ./data/png_FullIJCNN2013/00837.png
# ./data/png_FullIJCNN2013/00012.png
# ./data/png_FullIJCNN2013/00023.png
# ./data/png_FullIJCNN2013/00846.png
# ./data/png_FullIJCNN2013/00750.png
# ./data/png_FullIJCNN2013/00602.png
# ./data/png_FullIJCNN2013/00403.png
# ./data/png_FullIJCNN2013/00774.png
# ./data/png_FullIJCNN2013/00168.png
# ./data/png_FullIJCNN2013/00080.png
# ./data/png_FullIJCNN2013/00414.png
# ./data/png_FullIJCNN2013/00553.png
# ./data/png_FullIJCNN2013/00829.png
# ./data/png_FullIJCNN2013/00821.png
# ./data/png_FullIJCNN2013/00861.png
# ./data/png_FullIJCNN2013/00127.png
# ./data/png_FullIJCNN2013/00372.png
# ./data/png_FullIJCNN2013/00586.png
# ./data/png_FullIJCNN2013/00119.png
# ./data/png_FullIJCNN2013/00822.png
# ./data/png_FullIJCNN2013/00607.png
# ./data/png_FullIJCNN2013/00077.png
# ./data/png_FullIJCNN2013/00573.png
# ./data/png_FullIJCNN2013/00276.png
# ./data/png_FullIJCNN2013/00516.png
# ./data/png_FullIJCNN2013/00239.png
# ./data/png_FullIJCNN2013/00439.png
# ./data/png_FullIJCNN2013/00691.png
# ./data/png_FullIJCNN2013/00060.png
# ./data/png_FullIJCNN2013/00855.png
# ./data/png_FullIJCNN2013/00315.png
# ./data/png_FullIJCNN2013/00503.png
# ./data/png_FullIJCNN2013/00543.png
# ./data/png_FullIJCNN2013/00720.png
# ./data/png_FullIJCNN2013/00361.png
# ./data/png_FullIJCNN2013/00565.png
# ./data/png_FullIJCNN2013/00743.png
# ./data/png_FullIJCNN2013/00867.png
# ./data/png_FullIJCNN2013/00293.png
# ./data/png_FullIJCNN2013/00478.png
# ./data/png_FullIJCNN2013/00311.png
# ./data/png_FullIJCNN2013/00603.png
# ./data/png_FullIJCNN2013/00236.png
# ./data/png_FullIJCNN2013/00856.png
# ./data/png_FullIJCNN2013/00762.png
# ./data/png_FullIJCNN2013/00643.png
# ./data/png_FullIJCNN2013/00289.png
# ./data/png_FullIJCNN2013/00178.png
# ./data/png_FullIJCNN2013/00257.png
# ./data/png_FullIJCNN2013/00640.png
# ./data/png_FullIJCNN2013/00162.png
# ./data/png_FullIJCNN2013/00322.png
# ./data/png_FullIJCNN2013/00680.png
# ./data/png_FullIJCNN2013/00209.png
# ./data/png_FullIJCNN2013/00806.png
# ./data/png_FullIJCNN2013/00018.png
# ./data/png_FullIJCNN2013/00486.png
# ./data/png_FullIJCNN2013/00508.png
# ./data/png_FullIJCNN2013/00561.png
# ./data/png_FullIJCNN2013/00512.png
# ./data/png_FullIJCNN2013/00440.png
# ./data/png_FullIJCNN2013/00531.png
# ./data/png_FullIJCNN2013/00628.png
# ./data/png_FullIJCNN2013/00237.png
# ./data/png_FullIJCNN2013/00312.png
# ./data/png_FullIJCNN2013/00632.png
# ./data/png_FullIJCNN2013/00579.png
# ./data/png_FullIJCNN2013/00887.png
# ./data/png_FullIJCNN2013/00074.png
# ./data/png_FullIJCNN2013/00756.png
# ./data/png_FullIJCNN2013/00576.png
# ./data/png_FullIJCNN2013/00758.png
# ./data/png_FullIJCNN2013/00582.png
# ./data/png_FullIJCNN2013/00099.png
# ./data/png_FullIJCNN2013/00395.png
# ./data/png_FullIJCNN2013/00026.png
# ./data/png_FullIJCNN2013/00007.png
# ./data/png_FullIJCNN2013/00584.png
# ./data/png_FullIJCNN2013/00591.png
# ./data/png_FullIJCNN2013/00511.png
# ./data/png_FullIJCNN2013/00665.png
# ./data/png_FullIJCNN2013/00215.png
# ./data/png_FullIJCNN2013/00808.png
# ./data/png_FullIJCNN2013/00380.png
# ./data/png_FullIJCNN2013/00006.png
# ./data/png_FullIJCNN2013/00398.png
# ./data/png_FullIJCNN2013/00642.png
# ./data/png_FullIJCNN2013/00457.png
# ./data/png_FullIJCNN2013/00429.png
# ./data/png_FullIJCNN2013/00840.png
# ./data/png_FullIJCNN2013/00122.png
# ./data/png_FullIJCNN2013/00527.png
# ./data/png_FullIJCNN2013/00722.png
# ./data/png_FullIJCNN2013/00444.png
# ./data/png_FullIJCNN2013/00843.png
# ./data/png_FullIJCNN2013/00767.png
# ./data/png_FullIJCNN2013/00536.png
# ./data/png_FullIJCNN2013/00123.png
# ./data/png_FullIJCNN2013/00447.png
# ./data/png_FullIJCNN2013/00523.png
# ./data/png_FullIJCNN2013/00247.png
# ./data/png_FullIJCNN2013/00241.png
# ./data/png_FullIJCNN2013/00711.png
# ./data/png_FullIJCNN2013/00385.png
# ./data/png_FullIJCNN2013/00323.png
# ./data/png_FullIJCNN2013/00630.png
# ./data/png_FullIJCNN2013/00342.png
# ./data/png_FullIJCNN2013/00376.png
# ./data/png_FullIJCNN2013/00458.png
# ./data/png_FullIJCNN2013/00027.png
# ./data/png_FullIJCNN2013/00317.png
# ./data/png_FullIJCNN2013/00662.png
# ./data/png_FullIJCNN2013/00677.png
# ./data/png_FullIJCNN2013/00673.png
# ./data/png_FullIJCNN2013/00868.png
# ./data/png_FullIJCNN2013/00116.png
# ./data/png_FullIJCNN2013/00298.png
# ./data/png_FullIJCNN2013/00794.png
# ./data/png_FullIJCNN2013/00284.png
# ./data/png_FullIJCNN2013/00159.png
# ./data/png_FullIJCNN2013/00354.png
# ./data/png_FullIJCNN2013/00804.png
# ./data/png_FullIJCNN2013/00604.png
# ./data/png_FullIJCNN2013/00154.png
# ./data/png_FullIJCNN2013/00218.png
# ./data/png_FullIJCNN2013/00739.png
# ./data/png_FullIJCNN2013/00547.png
# ./data/png_FullIJCNN2013/00669.png
# ./data/png_FullIJCNN2013/00453.png
# ./data/png_FullIJCNN2013/00807.png
# ./data/png_FullIJCNN2013/00795.png
# ./data/png_FullIJCNN2013/00552.png
# ./data/png_FullIJCNN2013/00715.png
# ./data/png_FullIJCNN2013/00490.png
# ./data/png_FullIJCNN2013/00382.png
# ./data/png_FullIJCNN2013/00488.png
# ./data/png_FullIJCNN2013/00297.png
# ./data/png_FullIJCNN2013/00442.png
# ./data/png_FullIJCNN2013/00755.png
# ./data/png_FullIJCNN2013/00438.png
# ./data/png_FullIJCNN2013/00187.png
# ./data/png_FullIJCNN2013/00454.png
# ./data/png_FullIJCNN2013/00502.png
# ./data/png_FullIJCNN2013/00610.png
# ./data/png_FullIJCNN2013/00362.png
# ./data/png_FullIJCNN2013/00347.png
# ./data/png_FullIJCNN2013/00661.png
# ./data/png_FullIJCNN2013/00540.png
# ./data/png_FullIJCNN2013/00625.png
# ./data/png_FullIJCNN2013/00828.png
# ./data/png_FullIJCNN2013/00850.png
# ./data/png_FullIJCNN2013/00623.png
# ./data/png_FullIJCNN2013/00167.png
# ./data/png_FullIJCNN2013/00223.png
# ./data/png_FullIJCNN2013/00624.png
# ./data/png_FullIJCNN2013/00353.png
# ./data/png_FullIJCNN2013/00155.png
# ./data/png_FullIJCNN2013/00697.png
# ./data/png_FullIJCNN2013/00544.png
# ./data/png_FullIJCNN2013/00863.png
# ./data/png_FullIJCNN2013/00184.png
# ./data/png_FullIJCNN2013/00055.png
# ./data/png_FullIJCNN2013/00110.png
# ./data/png_FullIJCNN2013/00229.png
# ./data/png_FullIJCNN2013/00417.png
# ./data/png_FullIJCNN2013/00109.png
# ./data/png_FullIJCNN2013/00318.png
# ./data/png_FullIJCNN2013/00400.png
# ./data/png_FullIJCNN2013/00851.png
# ./data/png_FullIJCNN2013/00255.png
# ./data/png_FullIJCNN2013/00191.png
# ./data/png_FullIJCNN2013/00702.png
# ./data/png_FullIJCNN2013/00551.png
# ./data/png_FullIJCNN2013/00687.png
# ./data/png_FullIJCNN2013/00314.png
# ./data/png_FullIJCNN2013/00352.png
# ./data/png_FullIJCNN2013/00399.png
# ./data/png_FullIJCNN2013/00056.png
# ./data/png_FullIJCNN2013/00227.png
# ./data/png_FullIJCNN2013/00513.png
# ./data/png_FullIJCNN2013/00046.png
# ./data/png_FullIJCNN2013/00693.png
# ./data/png_FullIJCNN2013/00445.png
# ./data/png_FullIJCNN2013/00135.png
# ./data/png_FullIJCNN2013/00815.png
# ./data/png_FullIJCNN2013/00386.png
# ./data/png_FullIJCNN2013/00062.png
# ./data/png_FullIJCNN2013/00335.png
# ./data/png_FullIJCNN2013/00612.png
# ./data/png_FullIJCNN2013/00041.png
# ./data/png_FullIJCNN2013/00546.png
# ./data/png_FullIJCNN2013/00133.png
# ./data/png_FullIJCNN2013/00600.png
# ./data/png_FullIJCNN2013/00448.png
# ./data/png_FullIJCNN2013/00001.png
# ./data/png_FullIJCNN2013/00140.png
# ./data/png_FullIJCNN2013/00729.png
# ./data/png_FullIJCNN2013/00419.png
# ./data/png_FullIJCNN2013/00893.png
# ./data/png_FullIJCNN2013/00245.png
# ./data/png_FullIJCNN2013/00896.png
# ./data/png_FullIJCNN2013/00092.png
# ./data/png_FullIJCNN2013/00530.png
# ./data/png_FullIJCNN2013/00141.png
# ./data/png_FullIJCNN2013/00371.png
# ./data/png_FullIJCNN2013/00145.png
# ./data/png_FullIJCNN2013/00138.png
# ./data/png_FullIJCNN2013/00302.png
# ./data/png_FullIJCNN2013/00672.png
# ./data/png_FullIJCNN2013/00358.png
# ./data/png_FullIJCNN2013/00148.png
# ./data/png_FullIJCNN2013/00157.png
# ./data/png_FullIJCNN2013/00469.png
# ./data/png_FullIJCNN2013/00699.png
# ./data/png_FullIJCNN2013/00719.png
# ./data/png_FullIJCNN2013/00197.png
# ./data/png_FullIJCNN2013/00105.png
# ./data/png_FullIJCNN2013/00746.png
# ./data/png_FullIJCNN2013/00278.png
# ./data/png_FullIJCNN2013/00000.png
# ./data/png_FullIJCNN2013/00522.png
# ./data/png_FullIJCNN2013/00201.png
# ./data/png_FullIJCNN2013/00724.png
# ./data/png_FullIJCNN2013/00047.png
# ./data/png_FullIJCNN2013/00845.png
# ./data/png_FullIJCNN2013/00455.png
# ./data/png_FullIJCNN2013/00303.png
# ./data/png_FullIJCNN2013/00675.png
# ./data/png_FullIJCNN2013/00422.png
# ./data/png_FullIJCNN2013/00705.png
# ./data/png_FullIJCNN2013/00242.png
# ./data/png_FullIJCNN2013/00528.png
# ./data/png_FullIJCNN2013/00526.png
# ./data/png_FullIJCNN2013/00510.png
# ./data/png_FullIJCNN2013/00875.png
# ./data/png_FullIJCNN2013/00811.png
# ./data/png_FullIJCNN2013/00663.png
# ./data/png_FullIJCNN2013/00043.png
# ./data/png_FullIJCNN2013/00173.png
# ./data/png_FullIJCNN2013/00831.png
# ./data/png_FullIJCNN2013/00412.png
# ./data/png_FullIJCNN2013/00671.png
# ./data/png_FullIJCNN2013/00059.png
# ./data/png_FullIJCNN2013/00225.png
# ./data/png_FullIJCNN2013/00085.png
# ./data/png_FullIJCNN2013/00790.png
# ./data/png_FullIJCNN2013/00622.png
# ./data/png_FullIJCNN2013/00694.png
# ./data/png_FullIJCNN2013/00265.png
# ./data/png_FullIJCNN2013/00465.png
# ./data/png_FullIJCNN2013/00279.png
# ./data/png_FullIJCNN2013/00830.png
# ./data/png_FullIJCNN2013/00768.png
# ./data/png_FullIJCNN2013/00588.png
# ./data/png_FullIJCNN2013/00067.png
# ./data/png_FullIJCNN2013/00521.png
# ./data/png_FullIJCNN2013/00870.png
# ./data/png_FullIJCNN2013/00124.png
# ./data/png_FullIJCNN2013/00163.png
# ./data/png_FullIJCNN2013/00567.png
# ./data/png_FullIJCNN2013/00735.png
# ./data/png_FullIJCNN2013/00170.png
# ./data/png_FullIJCNN2013/00842.png
# ./data/png_FullIJCNN2013/00272.png
# ./data/png_FullIJCNN2013/00771.png
# ./data/png_FullIJCNN2013/00518.png
# ./data/png_FullIJCNN2013/00136.png
# ./data/png_FullIJCNN2013/00479.png
# ./data/png_FullIJCNN2013/00608.png
# ./data/png_FullIJCNN2013/00413.png
# ./data/png_FullIJCNN2013/00730.png
# ./data/png_FullIJCNN2013/00334.png
# ./data/png_FullIJCNN2013/00374.png
# ./data/png_FullIJCNN2013/00446.png
# ./data/png_FullIJCNN2013/00299.png
# ./data/png_FullIJCNN2013/00130.png
# ./data/png_FullIJCNN2013/00329.png
# ./data/png_FullIJCNN2013/00430.png
# ./data/png_FullIJCNN2013/00664.png
# ./data/png_FullIJCNN2013/00132.png
# ./data/png_FullIJCNN2013/00087.png
# ./data/png_FullIJCNN2013/00581.png
# ./data/png_FullIJCNN2013/00690.png
# ./data/png_FullIJCNN2013/00621.png
# ./data/png_FullIJCNN2013/00879.png
# ./data/png_FullIJCNN2013/00282.png
# ./data/png_FullIJCNN2013/00580.png
# ./data/png_FullIJCNN2013/00326.png
# ./data/png_FullIJCNN2013/00742.png
# ./data/png_FullIJCNN2013/00304.png
# ./data/png_FullIJCNN2013/00058.png
# ./data/png_FullIJCNN2013/00598.png
# ./data/png_FullIJCNN2013/00253.png
# ./data/png_FullIJCNN2013/00745.png
# ./data/png_FullIJCNN2013/00881.png
# ./data/png_FullIJCNN2013/00156.png
# ./data/png_FullIJCNN2013/00683.png
# ./data/png_FullIJCNN2013/00792.png
# ./data/png_FullIJCNN2013/00396.png
# ./data/png_FullIJCNN2013/00467.png
# ./data/png_FullIJCNN2013/00365.png
# ./data/png_FullIJCNN2013/00709.png
# ./data/png_FullIJCNN2013/00638.png
# ./data/png_FullIJCNN2013/00566.png
# ./data/png_FullIJCNN2013/00710.png
# ./data/png_FullIJCNN2013/00169.png
# ./data/png_FullIJCNN2013/00079.png
# ./data/png_FullIJCNN2013/00031.png
# ./data/png_FullIJCNN2013/00789.png
# ./data/png_FullIJCNN2013/00264.png
# ./data/png_FullIJCNN2013/00228.png
# ./data/png_FullIJCNN2013/00081.png
# ./data/png_FullIJCNN2013/00718.png
# ./data/png_FullIJCNN2013/00559.png
# ./data/png_FullIJCNN2013/00483.png
# ./data/png_FullIJCNN2013/00332.png
# ./data/png_FullIJCNN2013/00732.png
# ./data/png_FullIJCNN2013/00333.png
# ./data/png_FullIJCNN2013/00207.png
# ./data/png_FullIJCNN2013/00817.png
# ./data/png_FullIJCNN2013/00260.png
# ./data/png_FullIJCNN2013/00002.png
# ./data/png_FullIJCNN2013/00321.png
# ./data/png_FullIJCNN2013/00351.png
# ./data/png_FullIJCNN2013/00618.png
# ./data/png_FullIJCNN2013/00210.png
# ./data/png_FullIJCNN2013/00860.png
# ./data/png_FullIJCNN2013/00407.png
# ./data/png_FullIJCNN2013/00287.png
# ./data/png_FullIJCNN2013/00534.png
# ./data/png_FullIJCNN2013/00854.png
# ./data/png_FullIJCNN2013/00833.png
# ./data/png_FullIJCNN2013/00198.png
# ./data/png_FullIJCNN2013/00294.png
# ./data/png_FullIJCNN2013/00181.png
# ./data/png_FullIJCNN2013/00152.png
# ./data/png_FullIJCNN2013/00117.png
# ./data/png_FullIJCNN2013/00022.png
# ./data/png_FullIJCNN2013/00404.png
# ./data/png_FullIJCNN2013/00595.png
# ./data/png_FullIJCNN2013/00243.png
# ./data/png_FullIJCNN2013/00678.png
# ./data/png_FullIJCNN2013/00024.png
# ./data/png_FullIJCNN2013/00658.png
# ./data/png_FullIJCNN2013/00883.png
# ./data/png_FullIJCNN2013/00721.png
# ./data/png_FullIJCNN2013/00799.png
# ./data/png_FullIJCNN2013/00862.png
# ./data/png_FullIJCNN2013/00331.png
# ./data/png_FullIJCNN2013/00020.png
# ./data/png_FullIJCNN2013/00617.png
# ./data/png_FullIJCNN2013/00392.png
# ./data/png_FullIJCNN2013/00083.png
# ./data/png_FullIJCNN2013/00426.png
# ./data/png_FullIJCNN2013/00895.png
# ./data/png_FullIJCNN2013/00571.png
# ./data/png_FullIJCNN2013/00111.png
# ./data/png_FullIJCNN2013/00150.png
# ./data/png_FullIJCNN2013/00277.png
# ./data/png_FullIJCNN2013/00213.png
# ./data/png_FullIJCNN2013/00784.png
# ./data/png_FullIJCNN2013/00256.png
# ./data/png_FullIJCNN2013/00262.png
# ./data/png_FullIJCNN2013/00106.png
# ./data/png_FullIJCNN2013/00153.png
# ./data/png_FullIJCNN2013/00069.png
# ./data/png_FullIJCNN2013/00515.png
# ./data/png_FullIJCNN2013/00577.png
# ./data/png_FullIJCNN2013/00176.png
# ./data/png_FullIJCNN2013/00809.png
# ./data/png_FullIJCNN2013/00090.png
# ./data/png_FullIJCNN2013/00749.png
# ./data/png_FullIJCNN2013/00234.png
# ./data/png_FullIJCNN2013/00532.png
# ./data/png_FullIJCNN2013/00364.png
# ./data/png_FullIJCNN2013/00495.png
# ./data/png_FullIJCNN2013/00216.png
# ./data/png_FullIJCNN2013/00557.png
# ./data/png_FullIJCNN2013/00300.png
# ./data/png_FullIJCNN2013/00723.png
# ./data/png_FullIJCNN2013/00716.png
# ./data/png_FullIJCNN2013/00200.png
# ./data/png_FullIJCNN2013/00542.png
# ./data/png_FullIJCNN2013/00175.png
# ./data/png_FullIJCNN2013/00688.png
# ./data/png_FullIJCNN2013/00401.png
# ./data/png_FullIJCNN2013/00261.png
# ./data/png_FullIJCNN2013/00635.png
# ./data/png_FullIJCNN2013/00639.png
# ./data/png_FullIJCNN2013/00182.png
# ./data/png_FullIJCNN2013/00310.png
# ./data/png_FullIJCNN2013/00820.png
# ./data/png_FullIJCNN2013/00500.png
# ./data/png_FullIJCNN2013/00428.png
# ./data/png_FullIJCNN2013/00451.png
# ./data/png_FullIJCNN2013/00648.png
# ./data/png_FullIJCNN2013/00082.png
# ./data/png_FullIJCNN2013/00269.png
# ./data/png_FullIJCNN2013/00864.png
# ./data/png_FullIJCNN2013/00146.png
# ./data/png_FullIJCNN2013/00708.png
# ./data/png_FullIJCNN2013/00537.png
# ./data/png_FullIJCNN2013/00131.png
# ./data/png_FullIJCNN2013/00093.png
# ./data/png_FullIJCNN2013/00063.png
# ./data/png_FullIJCNN2013/00097.png
# ./data/png_FullIJCNN2013/00192.png
# ./data/png_FullIJCNN2013/00029.png
# ./data/png_FullIJCNN2013/00427.png
# ./data/png_FullIJCNN2013/00636.png
# ./data/png_FullIJCNN2013/00068.png
# ./data/png_FullIJCNN2013/00280.png
# ./data/png_FullIJCNN2013/00801.png
# ./data/png_FullIJCNN2013/00348.png
# ./data/png_FullIJCNN2013/00367.png
# ./data/png_FullIJCNN2013/00627.png
# ./data/png_FullIJCNN2013/00594.png

# %% [markdown]
# ## Detection with trained model

# %%
# import
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

#if tf.__version__ != '1.4.0':
#    raise ImportError('Please upgrade your tensorflow installation to v1.4.0!')

# Enviroment set up
# This is needed to display the images.
# %matplotlib inline

# 如果发现无法找到object_detection，则进行下面的code进行路径加载，或者启动notebook时，能指定到
# This is needed since the notebook is stored in the object_detection folder.
# sys.path.append("..")

from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util


# Path to frozen detection graph. This is the actual model that is used for the object detection.
#PATH_TO_CKPT = './model_pb/rfcn/frozen_inference_graph.pb'
PATH_TO_CKPT = './model_pb/frozen_inference_graph.pb'
data_dir = './data'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join(data_dir, 'gtsdb.pbtxt')

#PATH_TO_LABELS = os.path.join(data_dir, 'object-detection.pbtxt')

NUM_CLASSES = 43

# Load model
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')
    
# Loading label map 
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
              (im_height, im_width, 3)).astype(np.uint8)


# For the sake of simplicity we will use only 2 images:
# image1.jpg
# image2.jpg
# If you want to test the code with your images, just add path to the images to the TEST_IMAGE_PATHS.
#PATH_TO_TEST_IMAGES_DIR = os.path.join(data_dir, 'TestIJCNN2013')
PATH_TO_TEST_IMAGES_DIR = os.path.join(data_dir, 'test_samples')
TEST_IMAGE_PATHS = [ os.path.join(PATH_TO_TEST_IMAGES_DIR, '0000{}.png'.format(i)) for i in range(2, 3) ]
#TEST_IMAGE_PATHS = [ os.path.join(PATH_TO_TEST_IMAGES_DIR, '{}.jpg'.format(i)) for i in range(1, 2) ]
# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)


with detection_graph.as_default():
  with tf.Session(graph=detection_graph) as sess:
    # Definite input and output Tensors for detection_graph
    image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
    # Each box represents a part of the image where a particular object was detected.
    detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
    # Each score represent how level of confidence for each of the objects.
    # Score is shown on the result image, together with the class label.
    detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
    detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
    num_detections = detection_graph.get_tensor_by_name('num_detections:0')
    for image_path in TEST_IMAGE_PATHS:
      image = Image.open(image_path)
      # the array based representation of the image will be used later in order to prepare the
      # result image with boxes and labels on it.
      image_np = load_image_into_numpy_array(image)
      # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
      image_np_expanded = np.expand_dims(image_np, axis=0)
      # Actual detection.
      (boxes, scores, classes, num) = sess.run(
          [detection_boxes, detection_scores, detection_classes, num_detections],
          feed_dict={image_tensor: image_np_expanded})
      # Visualization of the results of a detection.
      print(scores,classes)
      vis_util.visualize_boxes_and_labels_on_image_array(
          image_np,
          np.squeeze(boxes),
          np.squeeze(classes).astype(np.int32),
          np.squeeze(scores),
          category_index,
          use_normalized_coordinates=True,
          line_thickness=8)
      plt.figure(figsize=IMAGE_SIZE)
      plt.imshow(image_np)
# Out:
# [[ 0.76746356  0.57839543  0.42553115  0.28233221  0.12435466  0.09267663
#    0.08675713  0.0719574   0.00599969  0.00472642]] [[ 11.   9.   9.   8.   6.   5.   6.  11.   7.  39.]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-da877469c46f> in <module>()
#     100           category_index,
#     101           use_normalized_coordinates=True,
# --> 102           line_thickness=8)
#     103       plt.figure(figsize=IMAGE_SIZE)
#     104       plt.imshow(image_np)
#
# /media/xufq/E8F025C4F02599B8/Cargo_FC2017/model_Traffic-Signal-Detect/src/object_detection/utils/visualization_utils.py in visualize_boxes_and_labels_on_image_array(image, boxes, classes, scores, category_index, instance_masks, keypoints, use_normalized_coordinates, max_boxes_to_draw, min_score_thresh, agnostic_mode, line_thickness)
#     484         use_normalized_coordinates=use_normalized_coordinates)
#     485     if keypoints is not None:
# --> 486       draw_keypoints_on_image_array(
#     487           image,
#     488           box_to_keypoints_map[box],
#
# /media/xufq/E8F025C4F02599B8/Cargo_FC2017/model_Traffic-Signal-Detect/src/object_detection/utils/visualization_utils.py in draw_bounding_box_on_image_array(image, ymin, xmin, ymax, xmax, color, thickness, display_str_list, use_normalized_coordinates)
#     118   draw_bounding_box_on_image(image_pil, ymin, xmin, ymax, xmax, color,
#     119                              thickness, display_str_list,
# --> 120                              use_normalized_coordinates)
#     121   np.copyto(image, np.array(image_pil))
#     122
#
# /media/xufq/E8F025C4F02599B8/Cargo_FC2017/model_Traffic-Signal-Detect/src/object_detection/utils/visualization_utils.py in draw_bounding_box_on_image(image, ymin, xmin, ymax, xmax, color, thickness, display_str_list, use_normalized_coordinates)
#     171   display_str_heights = [font.getsize(ds)[1] for ds in display_str_list]
#     172   # Each display_str has a top and bottom margin of 0.05x.
# --> 173   total_display_str_height = (1 + 2 * 0.05) * sum(display_str_heights)
#     174
#     175   if top > total_display_str_height:
#
# /media/xufq/E8F025C4F02599B8/Cargo_FC2017/model_Traffic-Signal-Detect/src/object_detection/utils/visualization_utils.py in <listcomp>(.0)
#     171   display_str_heights = [font.getsize(ds)[1] for ds in display_str_list]
#     172   # Each display_str has a top and bottom margin of 0.05x.
# --> 173   total_display_str_height = (1 + 2 * 0.05) * sum(display_str_heights)
#     174
#     175   if top > total_display_str_height:
#
# ~/miniconda3/envs/tensorflow/lib/python3.5/site-packages/PIL/ImageFont.py in getsize(self, text, direction, features)
#     154
#     155     def getsize(self, text, direction=None, features=None):
# --> 156         size, offset = self.font.getsize(text, direction, features)
#     157         return (size[0] + offset[0], size[1] + offset[1])
#     158
#
# TypeError: expected string

# %%
#coding:utf-8
"""
使用说明:
    输入输出:
        1. 读取test_images里面的文件进行推理,输出到output/TSD-Signal-Result-Cargo目录
        2. test_images下的图片位置为TSD-Signal-**/*.png
        3. 输出xml的文件名就是上面图片的目录名TSD-Signal-**
        4. 所有路径指定在页面底部.
    功能:
        1. 得到推理结果xml,用于提交
        2. 得到推理结果图片,用于调试
        3. 得到F1等统计结果,用于调试

"""
import os
import sys
import cv2
import glob
import shutil
import configparser
import numpy as np
import tensorflow as tf

from tqdm import tqdm
from f1_score import Score
from write_xml import build_xml
from PIL import ImageFont, ImageDraw, Image

def get_label_dict(label_path):
    label_map_dict = {}
    label_list = []
    with open(label_path, 'r') as f:
        lines = f.readlines()
        for line in lines:
            if not line.split():
                continue
            line = line.strip()
            number, name = line.split(' ', 1)
            label_map_dict[name] = int(number)
            label_list.append(name)
            assert len(label_list) == int(number), str(label_list) + ' ' + number

    # assert len(label_map_dict) == 77
    return label_map_dict, label_list

def to_image_coords(boxes, height, width):
    box_coords = np.zeros_like(boxes)
    box_coords[:, 1] = boxes[:, 0] * height
    box_coords[:, 0] = boxes[:, 1] * width
    box_coords[:, 3] = boxes[:, 2] * height
    box_coords[:, 2] = boxes[:, 3] * width
    
    return box_coords

def draw_box_and_text(image, box, label, pred_score, font_size, font):
    pt1 = (int(box[0]), int(box[1]))
    pt2 = (int(box[2]), int(box[3]))
    # bounding object
    cv2.rectangle(image, pt1, pt2, (255, 0, 0), 2)
    # label text and box
    label_text = "{}: {:.1f}%".format(label, pred_score*100)
    label_w, label_h= int(14.5*len(label_text)+4), font_size+4
    label_start = (pt2[0], pt1[1])
    # TODO: 多标签重叠处理
    # 如果x标签超出了最右边：
    #   如果y标签不会超出最上边，移动到上面显示
    #   如果y超出了最上面，移动到下面显示
    if label_start[0] + label_w > image.shape[1]:
        if label_start[1] - label_h > 0:
            shift = (- label_w, - label_h - 1)
        else:
            shift = (- label_w, pt2[1]-pt1[1] + 2)
        label_start = (label_start[0] + shift[0], label_start[1] + shift[1])

    label_end = (label_start[0] + label_w, label_start[1] + label_h)
    cv2.rectangle(image, label_start, label_end, (0, 255, 0), -1)
    
    # 转换为PIL写入中文后再转为cv2
    cv2_im = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # cv2和PIL中颜色的hex码的储存顺序不同
    pil_im = Image.fromarray(cv2_im)
    drawObject = ImageDraw.Draw(pil_im) 
    drawObject.text((label_start[0] + 2, label_start[1] + 2), label_text,"red", font=font)
    image = cv2.cvtColor(np.array(pil_im), cv2.COLOR_RGB2BGR)    

    return image
# 非极大值抑制 from: http://blog.csdn.net/gan_player/article/details/78204960
def py_cpu_nms(dets, thresh):
    """Pure Python NMS baseline."""
    if len(dets) == 0:
        return []
    x1 = dets[:, 0]
    y1 = dets[:, 1]
    x2 = dets[:, 2]
    y2 = dets[:, 3]
    scores = dets[:, 4]

    areas = (x2 - x1 + 1) * (y2 - y1 + 1)
    #从大到小排列，取index
    order = scores.argsort()[::-1]  #逆序排序
    #keep为最后保留的边框
    keep = []
    while order.size > 0:
        #order[0]是当前分数最大的窗口，之前没有被过滤掉，肯定是要保留的
        i = order[0]
        keep.append(i)

        #计算窗口i与其他所以窗口的交叠部分的面积，矩阵计算
        xx1 = np.maximum(x1[i], x1[order[1:]])
        yy1 = np.maximum(y1[i], y1[order[1:]])
        xx2 = np.minimum(x2[i], x2[order[1:]])
        yy2 = np.minimum(y2[i], y2[order[1:]])

        w = np.maximum(0.0, xx2 - xx1 + 1)
        h = np.maximum(0.0, yy2 - yy1 + 1)
        inter = w * h
        #交/并得到iou值
        ovr = inter / (areas[i] + areas[order[1:]] - inter)
        #ind为所有与窗口i的iou值小于threshold值的窗口的index，其他窗口此次都被窗口i吸收
        inds = np.where(ovr <= thresh)[0]
        #下一次计算前要把窗口i去除，所有i对应的在order里的位置是0，所以剩下的加1
        order = order[inds + 1]
    return keep


def load_graph():
    detection_graph = tf.Graph()
    with detection_graph.as_default():
        od_graph_def = tf.GraphDef()
        with tf.gfile.GFile(pb_path, 'rb') as fid:
            serialized_graph = fid.read()
            od_graph_def.ParseFromString(serialized_graph)
            tf.import_graph_def(od_graph_def, name='')

    return detection_graph

def main():
    #score = Score(GT_xmls_dir)   
    cf = configparser.ConfigParser()
    cf.read('../config/traffic.config')    
    font_size = 20
    font = ImageFont.truetype(cf.get('font_path', 'simsun'), font_size) 
    #font = ImageFont.truetype('FreeSerif.ttf', font_size)

    _, label_list = get_label_dict(label_path)
    detection_graph = load_graph()
    with detection_graph.as_default():
        with tf.Session(graph=detection_graph) as sess:
            image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
            detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
            detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
            detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
            num_detections = detection_graph.get_tensor_by_name('num_detections:0')
            ii = 0
  
            for image_name in os.listdir(img_dir):
            #for image_name in ['00000.png','00001.png','00002.png','00003.png','00004.png','00005.png','00006.png','00007.png','00008.png','00009.png']:
                image_path = os.path.join(img_dir, image_name)
                image = cv2.imread(image_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # TODO
                (im_height, im_width, _) = image.shape
                image_np_expanded = np.expand_dims(image, axis=0)
                (boxes, scores, classes, num) = sess.run(
                        [detection_boxes, detection_scores, detection_classes, num_detections],
                        feed_dict={image_tensor: image_np_expanded})
                box_coords = to_image_coords(boxes[0], im_height, im_width)
                    
                # 获得符合最低置信度的预测结果
                pred_idx = []
                for i, pred in enumerate(scores[0]):
                    if pred > pred_threshold:
                        pred_idx.append([i, pred])

                targets = []
                dets = []
                for idx, pred in pred_idx:
                    clazz = int(classes[0][idx:idx+1][0])
                    label = label_list[clazz-1]   
                    box = box_coords[idx:idx+1][0]
                    targets.append([label, box, pred])
                    dets.append([box[0], box[1], box[2], box[3], pred])
                dets = np.array(dets)
                    
                # 非极大值抑制
                y = py_cpu_nms(dets, 0.3)
                a = len(targets) - len(y)
                if a > 0: print('NMS Droped: ', a)
                targets = [targets[i] for i in y]
                # 写入结果框到image
                for label, box, pred in targets:
                    image = draw_box_and_text(image, box, label, pred, font_size, font)
                    
                # 计算score
                # is_pass = score.update(image_name, img_dir, targets)
                    
                # 生成结果图片 正确的和错误的分开保存
                #if is_gen_img:
                #    if not is_pass: # TODO : 真值 box和type写入
                #        cv2.imwrite(os.path.join(fail_case_dir, image_name), image)                        
                #    else:
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                cv2.imwrite(os.path.join(img_result_dir, image_name), image)

    return score

data_dir = '../data'
output_dir = '../output'
test_dir = os.path.join(data_dir, 'test_samples')
img_dir = test_dir
label_path = os.path.join(data_dir,'gtsdb.label')
img_result_dir = os.path.join(output_dir, 'test_result')

pb_path = './model_pb/rfcn/frozen_inference_graph.pb'
#pb_path = './model_pb/rcnn_resnet50/frozen_inference_graph.pb'

pred_threshold = 0.3

# 是否生成带框的结果图片
is_gen_img = True


if __name__ == '__main__':

    if os.path.exists(img_result_dir):
        shutil.rmtree(img_result_dir)
    os.makedirs(img_result_dir)    
    
   
    score = main()
    '''
    f1, precision, recall = score.get_f1_score() 

    acc, total = score.get_combine_accuracy()
    box_acc = score.get_box_accuracy()

    print(score.TP, score.FP, score.box_TP, score.box_FP)

    #print("F1 score: %.2f, precision: %.2f, recall: %.2f" %(f1, precision, recall))
    print('Total: ', total, ", Accuracy: ", format(acc,'0.1%'))
    print("box_acc: ", format(box_acc,'0.1%'))
    print("box match but type not match count: ", score.type_missed_count)

    '''
# Out:
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  2
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  2
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# NMS Droped:  1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-795c30839a1d> in <module>()
#     226
#     227
# --> 228     score = main()
#     229     '''
#     230     f1, precision, recall = score.get_f1_score()
#
# <ipython-input-20-795c30839a1d> in main()
#     201                 cv2.imwrite(os.path.join(img_result_dir, image_name), image)
#     202
# --> 203     return score
#     204
#     205 data_dir = '../data'
#
# NameError: name 'score' is not defined
